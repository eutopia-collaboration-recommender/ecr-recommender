# %% [markdown]
# # Results interpretation

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_filepath = '../results/results_EuCoHM.csv'

# %%
df = pd.read_csv(csv_filepath)
df.head(5)
# Out:
#    epoch  train_loss_bpr  test_loss_bpr  precision@k  recall@k     map@k  \
# 0      1        0.024130       0.988238     0.012221  0.023341  0.013009
# 1      2        0.039368       0.258204     0.028378  0.056104  0.028215
# 2      3        0.019172       0.201016     0.039098  0.077241  0.041739
# 3      4        0.014715       0.137486     0.047294  0.094777  0.051194
# 4      5        0.012124       0.112182     0.051456  0.104160  0.055654
#
#       mrr@k    ndcg@k  hit_rate@k
# 0  0.019482  0.018742    0.044688
# 1  0.048194  0.043992    0.119061
# 2  0.068550  0.062380    0.160119
# 3  0.085403  0.076319    0.191095
# 4  0.094066  0.083482    0.211422

# %%
# Generate loss curve
plt.plot(df['epoch'], df['train_loss_bpr'], label='train')
plt.plot(df['epoch'], df['test_loss_bpr'], label='test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.show()

# %%
# Generate evaluation metrics plot
plt.plot(df['epoch'], df['precision@k'], label='precision@k')
plt.plot(df['epoch'], df['recall@k'], label='recall@k')
plt.plot(df['epoch'], df['map@k'], label='map@k')
plt.plot(df['epoch'], df['mrr@k'], label='mrr@k')
plt.plot(df['epoch'], df['ndcg@k'], label='ndcg@k')
plt.plot(df['epoch'], df['hit_rate@k'], label='hit_rate@k')
plt.xlabel('Epoch')
plt.ylabel('Performance')
plt.title('Evaluation metrics')
plt.legend()
plt.show()
