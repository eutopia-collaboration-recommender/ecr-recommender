# %% [markdown]
# # Model G
#
# This is a script showing results of **model G** in the ablation studies. The model is built using the following configuration:
#
# - **Backbone:** GATv2
# - **Graph type:** Heterogeneous
# - **Loss function:** Bayesian Personalized Ranking Loss
# - **Embeddings used:** average
# - **Keyword popularity used:** No
#
# *This model introduces a heterogeneous version of the graph attention network backbone.*

# %% [markdown]
# ## **Setting up environment**
#
# ---

# %% [markdown]
# ### Loading libraries

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))

import torch
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from typing import Optional

from torch import Tensor
from torch.nn import ModuleList
import torch.nn.functional as F
from torch.optim import Optimizer
from torch_geometric.typing import Adj, OptTensor
from torch_geometric.nn.conv import TransformerConv
from torch.optim.lr_scheduler import LRScheduler
from torch_geometric.data import Data

from util.torch_geometric import get_results
from util.heterogeneous.dataset import (DatasetEuCoHT, load_dataset)
from util.heterogeneous.model import ModelEuCoHT
from util.heterogeneous.train import (
    train,
    test,
    evaluate
)

# %% [markdown]
# ### Global variables

# %%
# Model name
model_name = 'G'
# Dataset save filepath
dataset_save_filepath_prefix = '../data/dataset_heterogeneous'
# Device name
device = 'cpu'

# Model configuration
model_config = dict(
    hidden_channels=64,
    learning_rate=1e-3,
    num_layers=4,
    num_epochs=50,
    num_recommendations=10,
    include_linear_layers=True,
    include_activation_layers=True,
    num_bootstrap=10
)
target_edge_type = ('author', 'co_authors', 'author')
target_node_type = 'author'

# Set seaborn theme
sns.set_theme(style="whitegrid", palette="pastel")

# %% [markdown]
# ## Model training
#
#
# ---

# %% [markdown]
# ### Model definition

# %%
class ModelEuCoG(ModelEuCoHT):
    def __init__(self,
                 input_channels: int,
                 hidden_channels: int,
                 num_layers: int,
                 num_recommendations: int,
                 author_node_id_map: dict,
                 author_id_map: dict,
                 include_linear_layers: bool,
                 include_activation_layers: bool):
        super().__init__(
            hidden_channels=hidden_channels,
            num_layers=num_layers,
            num_recommendations=num_recommendations,
            author_node_id_map=author_node_id_map,
            author_id_map=author_id_map,
            include_linear_layers=include_linear_layers,
            include_activation_layers=include_activation_layers
        )

# %% [markdown]
# ### Training the model

# %%
def load_model(data: Data, model_config: dict, author_node_id_map: dict, author_id_map: dict):
    # Initialize the model
    model = ModelEuCoG(
        input_channels=data.num_features,
        hidden_channels=model_config['hidden_channels'],
        num_recommendations=model_config['num_recommendations'],
        num_layers=model_config['num_layers'],
        author_node_id_map=author_node_id_map,
        author_id_map=author_id_map,
        include_linear_layers=model_config['include_linear_layers'],
        include_activation_layers=model_config['include_activation_layers']
    ).to(device)
    
    # Initialize the optimizer
    optimizer: Optimizer = torch.optim.Adam(
        params=model.parameters(),
        lr=model_config['learning_rate']
    )
    
    # Initialize the scheduler
    scheduler: LRScheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        mode='min',
        factor=0.5,
        patience=10
    )
    
    return model, data, optimizer, scheduler

# %%
results: list = list()
for bootstrap_id in range(model_config['num_bootstrap']):
    print(f'Processing bootstrap dataset ix={bootstrap_id}...')
    dataset_filepath = f'{dataset_save_filepath_prefix}_b{bootstrap_id}.pkl'
    data, author_id_map, author_node_id_map = load_dataset(dataset_filepath=dataset_filepath, device=device)
    model, data, optimizer, scheduler = load_model(data, model_config, author_node_id_map, author_id_map)
    for epoch in range(1, model_config['num_epochs'] + 1):
        # ------ Train
        train_loss: float = train(
            model=model,
            data=data,
            optimizer=optimizer,
            target_edge_type=target_edge_type,
            target_node_type=target_node_type
        )
        # ------ Test
        test_loss: float = test(
            model=model,
            data=data,
            target_edge_type=target_edge_type,
        )
        scheduler.step(test_loss)
        # ------ Evaluate
        evaluation_results: dict = evaluate(
            num_recommendations=model_config['num_recommendations'],
            model=model,
            data=data,
            target_edge_type=target_edge_type,
            target_node_type=target_node_type
        )
    
        # Save results
        epoch_result = get_results(
            epoch=epoch,
            train_loss=train_loss,
            test_loss=test_loss,
            evaluation_results=evaluation_results,
            bootstrap_id=bootstrap_id,
            log_every_n_epochs=10
        )
        results.append(epoch_result)
# Out:
# Processing bootstrap dataset ix=0...
# /home/eucollab/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Epoch 10, train loss: 0.0142, test loss: 3.3951, precision@k: 0.0052, recall@k: 0.0143, MAP@k: 0.0052, MRR@k: 0.0126, NDCG@k: 0.0096, HitRate@k: 0.0366
# Epoch 20, train loss: 0.0087, test loss: 3.6785, precision@k: 0.0076, recall@k: 0.0214, MAP@k: 0.0077, MRR@k: 0.0189, NDCG@k: 0.0143, HitRate@k: 0.0550
# Epoch 30, train loss: 0.0063, test loss: 3.6222, precision@k: 0.0089, recall@k: 0.0248, MAP@k: 0.0089, MRR@k: 0.0216, NDCG@k: 0.0166, HitRate@k: 0.0640
# Epoch 40, train loss: 0.0071, test loss: 3.5688, precision@k: 0.0094, recall@k: 0.0265, MAP@k: 0.0097, MRR@k: 0.0226, NDCG@k: 0.0177, HitRate@k: 0.0662
# Epoch 50, train loss: 0.0063, test loss: 3.4990, precision@k: 0.0096, recall@k: 0.0271, MAP@k: 0.0099, MRR@k: 0.0228, NDCG@k: 0.0181, HitRate@k: 0.0668
# Processing bootstrap dataset ix=1...
# Epoch 10, train loss: 0.0109, test loss: 3.7120, precision@k: 0.0071, recall@k: 0.0167, MAP@k: 0.0070, MRR@k: 0.0189, NDCG@k: 0.0128, HitRate@k: 0.0464
# Epoch 20, train loss: 0.0062, test loss: 4.1624, precision@k: 0.0094, recall@k: 0.0240, MAP@k: 0.0094, MRR@k: 0.0233, NDCG@k: 0.0171, HitRate@k: 0.0615
# Epoch 30, train loss: 0.0069, test loss: 4.0280, precision@k: 0.0104, recall@k: 0.0277, MAP@k: 0.0108, MRR@k: 0.0259, NDCG@k: 0.0195, HitRate@k: 0.0690
# Epoch 40, train loss: 0.0059, test loss: 3.9962, precision@k: 0.0105, recall@k: 0.0284, MAP@k: 0.0107, MRR@k: 0.0260, NDCG@k: 0.0196, HitRate@k: 0.0692
# Epoch 50, train loss: 0.0057, test loss: 3.9778, precision@k: 0.0107, recall@k: 0.0293, MAP@k: 0.0110, MRR@k: 0.0263, NDCG@k: 0.0200, HitRate@k: 0.0707
# Processing bootstrap dataset ix=2...
# Epoch 10, train loss: 0.0124, test loss: 2.9789, precision@k: 0.0060, recall@k: 0.0152, MAP@k: 0.0058, MRR@k: 0.0137, NDCG@k: 0.0106, HitRate@k: 0.0393
# Epoch 20, train loss: 0.0083, test loss: 3.8732, precision@k: 0.0082, recall@k: 0.0215, MAP@k: 0.0084, MRR@k: 0.0199, NDCG@k: 0.0152, HitRate@k: 0.0555
# Epoch 30, train loss: 0.0060, test loss: 3.9855, precision@k: 0.0097, recall@k: 0.0255, MAP@k: 0.0095, MRR@k: 0.0227, NDCG@k: 0.0176, HitRate@k: 0.0644
# Epoch 40, train loss: 0.0052, test loss: 3.9788, precision@k: 0.0099, recall@k: 0.0267, MAP@k: 0.0097, MRR@k: 0.0231, NDCG@k: 0.0181, HitRate@k: 0.0660
# Epoch 50, train loss: 0.0052, test loss: 3.9875, precision@k: 0.0101, recall@k: 0.0271, MAP@k: 0.0097, MRR@k: 0.0231, NDCG@k: 0.0182, HitRate@k: 0.0673
# Processing bootstrap dataset ix=3...
# Epoch 10, train loss: 0.0118, test loss: 3.9039, precision@k: 0.0055, recall@k: 0.0131, MAP@k: 0.0053, MRR@k: 0.0128, NDCG@k: 0.0096, HitRate@k: 0.0357
# Epoch 20, train loss: 0.0072, test loss: 3.8125, precision@k: 0.0082, recall@k: 0.0225, MAP@k: 0.0080, MRR@k: 0.0186, NDCG@k: 0.0148, HitRate@k: 0.0560
# Epoch 30, train loss: 0.0063, test loss: 3.7288, precision@k: 0.0093, recall@k: 0.0260, MAP@k: 0.0092, MRR@k: 0.0210, NDCG@k: 0.0171, HitRate@k: 0.0638
# Epoch 40, train loss: 0.0052, test loss: 3.6656, precision@k: 0.0099, recall@k: 0.0274, MAP@k: 0.0099, MRR@k: 0.0227, NDCG@k: 0.0182, HitRate@k: 0.0676
# Epoch 50, train loss: 0.0055, test loss: 3.6351, precision@k: 0.0100, recall@k: 0.0278, MAP@k: 0.0102, MRR@k: 0.0233, NDCG@k: 0.0186, HitRate@k: 0.0680
# Processing bootstrap dataset ix=4...
# Epoch 20, train loss: 0.0082, test loss: 4.3088, precision@k: 0.0075, recall@k: 0.0208, MAP@k: 0.0075, MRR@k: 0.0180, NDCG@k: 0.0139, HitRate@k: 0.0526
# Epoch 30, train loss: 0.0057, test loss: 3.9566, precision@k: 0.0087, recall@k: 0.0253, MAP@k: 0.0090, MRR@k: 0.0209, NDCG@k: 0.0166, HitRate@k: 0.0616
# Epoch 40, train loss: 0.0057, test loss: 3.7247, precision@k: 0.0091, recall@k: 0.0264, MAP@k: 0.0093, MRR@k: 0.0216, NDCG@k: 0.0173, HitRate@k: 0.0640
# Epoch 50, train loss: 0.0050, test loss: 3.6894, precision@k: 0.0092, recall@k: 0.0268, MAP@k: 0.0094, MRR@k: 0.0217, NDCG@k: 0.0175, HitRate@k: 0.0654
# Processing bootstrap dataset ix=5...
# Epoch 10, train loss: 0.0100, test loss: 2.8599, precision@k: 0.0038, recall@k: 0.0113, MAP@k: 0.0035, MRR@k: 0.0084, NDCG@k: 0.0069, HitRate@k: 0.0298
# Epoch 20, train loss: 0.0066, test loss: 3.6653, precision@k: 0.0062, recall@k: 0.0191, MAP@k: 0.0067, MRR@k: 0.0157, NDCG@k: 0.0124, HitRate@k: 0.0465
# Epoch 30, train loss: 0.0051, test loss: 3.8327, precision@k: 0.0087, recall@k: 0.0269, MAP@k: 0.0098, MRR@k: 0.0220, NDCG@k: 0.0176, HitRate@k: 0.0635
# Epoch 40, train loss: 0.0057, test loss: 3.7996, precision@k: 0.0093, recall@k: 0.0281, MAP@k: 0.0099, MRR@k: 0.0223, NDCG@k: 0.0182, HitRate@k: 0.0670
# Epoch 50, train loss: 0.0051, test loss: 3.6777, precision@k: 0.0095, recall@k: 0.0288, MAP@k: 0.0103, MRR@k: 0.0232, NDCG@k: 0.0188, HitRate@k: 0.0690
# Processing bootstrap dataset ix=6...
# Epoch 10, train loss: 0.0119, test loss: 3.1881, precision@k: 0.0057, recall@k: 0.0143, MAP@k: 0.0051, MRR@k: 0.0128, NDCG@k: 0.0097, HitRate@k: 0.0386
# Epoch 20, train loss: 0.0081, test loss: 3.6568, precision@k: 0.0075, recall@k: 0.0196, MAP@k: 0.0068, MRR@k: 0.0177, NDCG@k: 0.0131, HitRate@k: 0.0519
# Epoch 30, train loss: 0.0070, test loss: 3.4913, precision@k: 0.0088, recall@k: 0.0240, MAP@k: 0.0085, MRR@k: 0.0206, NDCG@k: 0.0160, HitRate@k: 0.0606
# Epoch 40, train loss: 0.0058, test loss: 3.4770, precision@k: 0.0095, recall@k: 0.0264, MAP@k: 0.0095, MRR@k: 0.0226, NDCG@k: 0.0176, HitRate@k: 0.0655
# Epoch 50, train loss: 0.0059, test loss: 3.5379, precision@k: 0.0098, recall@k: 0.0269, MAP@k: 0.0098, MRR@k: 0.0232, NDCG@k: 0.0181, HitRate@k: 0.0674
# Processing bootstrap dataset ix=7...
# Epoch 10, train loss: 0.0119, test loss: 5.0575, precision@k: 0.0050, recall@k: 0.0121, MAP@k: 0.0045, MRR@k: 0.0110, NDCG@k: 0.0084, HitRate@k: 0.0324
# Epoch 20, train loss: 0.0077, test loss: 5.4022, precision@k: 0.0066, recall@k: 0.0190, MAP@k: 0.0067, MRR@k: 0.0157, NDCG@k: 0.0125, HitRate@k: 0.0469
# Epoch 30, train loss: 0.0056, test loss: 4.7022, precision@k: 0.0085, recall@k: 0.0251, MAP@k: 0.0091, MRR@k: 0.0208, NDCG@k: 0.0165, HitRate@k: 0.0597
# Epoch 40, train loss: 0.0064, test loss: 4.4696, precision@k: 0.0089, recall@k: 0.0262, MAP@k: 0.0098, MRR@k: 0.0223, NDCG@k: 0.0175, HitRate@k: 0.0623
# Epoch 50, train loss: 0.0058, test loss: 4.4478, precision@k: 0.0090, recall@k: 0.0266, MAP@k: 0.0099, MRR@k: 0.0224, NDCG@k: 0.0177, HitRate@k: 0.0632
# Processing bootstrap dataset ix=8...
# Epoch 10, train loss: 0.0167, test loss: 4.3677, precision@k: 0.0056, recall@k: 0.0138, MAP@k: 0.0048, MRR@k: 0.0117, NDCG@k: 0.0092, HitRate@k: 0.0361
# Epoch 20, train loss: 0.0099, test loss: 4.6698, precision@k: 0.0073, recall@k: 0.0185, MAP@k: 0.0065, MRR@k: 0.0151, NDCG@k: 0.0122, HitRate@k: 0.0470
# Epoch 30, train loss: 0.0073, test loss: 4.1547, precision@k: 0.0083, recall@k: 0.0219, MAP@k: 0.0076, MRR@k: 0.0177, NDCG@k: 0.0143, HitRate@k: 0.0538
# Epoch 40, train loss: 0.0067, test loss: 4.6385, precision@k: 0.0083, recall@k: 0.0226, MAP@k: 0.0077, MRR@k: 0.0177, NDCG@k: 0.0146, HitRate@k: 0.0551
# Epoch 50, train loss: 0.0059, test loss: 4.1865, precision@k: 0.0091, recall@k: 0.0243, MAP@k: 0.0083, MRR@k: 0.0193, NDCG@k: 0.0158, HitRate@k: 0.0598
# Processing bootstrap dataset ix=9...
# Epoch 10, train loss: 0.0109, test loss: 3.9395, precision@k: 0.0036, recall@k: 0.0091, MAP@k: 0.0029, MRR@k: 0.0078, NDCG@k: 0.0059, HitRate@k: 0.0263
# Epoch 20, train loss: 0.0082, test loss: 3.8355, precision@k: 0.0073, recall@k: 0.0187, MAP@k: 0.0066, MRR@k: 0.0168, NDCG@k: 0.0127, HitRate@k: 0.0512
# Epoch 30, train loss: 0.0065, test loss: 3.5329, precision@k: 0.0094, recall@k: 0.0246, MAP@k: 0.0090, MRR@k: 0.0216, NDCG@k: 0.0168, HitRate@k: 0.0636
# Epoch 40, train loss: 0.0053, test loss: 3.4665, precision@k: 0.0098, recall@k: 0.0259, MAP@k: 0.0098, MRR@k: 0.0232, NDCG@k: 0.0179, HitRate@k: 0.0659
# Epoch 50, train loss: 0.0048, test loss: 3.4202, precision@k: 0.0100, recall@k: 0.0268, MAP@k: 0.0101, MRR@k: 0.0238, NDCG@k: 0.0184, HitRate@k: 0.0679

# %% [markdown]
# ### Model evaluation

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(f'../results/results_Model_bootstrapped_{model_name}.csv', index=False)

# %%
# Generate loss curve
# Train loss
sns.lineplot(data=results_df, x='Epoch', y='Train Loss')
# Test loss
sns.lineplot(data=results_df, x='Epoch', y='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss curve')
plt.yscale('log')
plt.show()

# %%
# Generate evaluation metrics plot
sns.lineplot(data=results_df, x='Epoch', y='Precision@k')
sns.lineplot(data=results_df, x='Epoch', y='Recall@k')
sns.lineplot(data=results_df, x='Epoch', y='MAP@k')
sns.lineplot(data=results_df, x='Epoch', y='MRR@k')
sns.lineplot(data=results_df, x='Epoch', y='NDCG@k')
sns.lineplot(data=results_df, x='Epoch', y='HitRate@k')
plt.xlabel('Epoch')
plt.ylabel('Performance')
plt.title('Performance metrics')
plt.show()
