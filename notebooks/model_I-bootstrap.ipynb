# %% [markdown]
# # Model I
#
# This is a script showing results of **model I** in the ablation studies. The model is built using the following configuration:
#
# - **Backbone:** GATv2
# - **Graph type:** Homogeneous
# - **Loss function:** Bayesian personalized ranking
# - **Embeddings used:** periodical average
# - **Keyword popularity used:** No
#
# *This model upgrades the state-of-the-art graph neural network methodology with novel graph transformer approach.*

# %% [markdown]
# ## **Setting up environment**
#
# ---

# %% [markdown]
# ### Loading libraries

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))

import torch
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from typing import Optional

from torch import Tensor
from torch.nn import ModuleList
from torch.optim import Optimizer
from torch_geometric.typing import Adj, OptTensor
from torch_geometric.nn.conv import TransformerConv
from torch.optim.lr_scheduler import LRScheduler
from torch_geometric.data import Data

from util.torch_geometric import get_results
from util.homogeneous.dataset import (DatasetEuCoHM, load_dataset)
from util.homogeneous.model import ModelEuCoHM
from util.homogeneous.train import (
    train,
    test,
    evaluate
)

# %% [markdown]
# ### Global variables

# %%
# Model name
model_name = 'I'
# Dataset save filepath
dataset_save_filepath_prefix = '../data/dataset_homogeneous_periodical_decay'
# Device name
device = 'cpu'

# Model configuration
model_config = dict(
    hidden_channels=128,
    learning_rate=1e-3,
    num_layers=4,
    num_epochs=50,
    num_recommendations=10,
    num_bootstrap=10
)
# Set seaborn theme
sns.set_theme(style="whitegrid", palette="pastel")

# %% [markdown]
# ## Model training
#
#
# ---

# %% [markdown]
# ### Model definition

# %%
class ModelEuCoI(ModelEuCoHM):
    def __init__(self,
                 input_channels: int,
                 hidden_channels: int,
                 num_layers: int,
                 num_recommendations: int,
                 author_node_id_map: dict,
                 author_id_map: dict,
                 device: str = 'cpu'):
        super().__init__(
            input_channels=input_channels,
            hidden_channels=hidden_channels,
            num_layers=num_layers,
            num_recommendations=num_recommendations,
            author_node_id_map=author_node_id_map,
            author_id_map=author_id_map,
            device=device
        )

# %% [markdown]
# ### Training the model

# %%
def load_model(data: Data, model_config: dict, author_node_id_map: dict, author_id_map: dict):
    # Initialize the model
    model = ModelEuCoI(
        input_channels=data.num_features,
        hidden_channels=model_config['hidden_channels'],
        num_recommendations=model_config['num_recommendations'],
        num_layers=model_config['num_layers'],
        author_node_id_map=author_node_id_map,
        author_id_map=author_id_map
    ).to(device)
    
    # Initialize the optimizer
    optimizer: Optimizer = torch.optim.Adam(
        params=model.parameters(),
        lr=model_config['learning_rate']
    )
    
    # Initialize the scheduler
    scheduler: LRScheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        mode='min',
        factor=0.5,
        patience=3
    )
    
    return model, data, optimizer, scheduler

# %%
results: list = list()
for bootstrap_id in range(model_config['num_bootstrap']):
    print(f'Processing bootstrap dataset ix={bootstrap_id}...')
    dataset_filepath = f'{dataset_save_filepath_prefix}_b{bootstrap_id}.pkl'
    data, author_id_map, author_node_id_map = load_dataset(dataset_filepath=dataset_filepath, device=device)
    model, data, optimizer, scheduler = load_model(data, model_config, author_node_id_map, author_id_map)
    for epoch in range(1, model_config['num_epochs'] + 1):
        # ------ Train
        train_loss: float = train(
            model=model,
            data=data,
            optimizer=optimizer
        )
        # ------ Test
        test_loss: float = test(
            model=model,
            data=data
        )
        scheduler.step(test_loss)
        # ------ Evaluate
        evaluation_results: dict = evaluate(
            k=model_config['num_recommendations'],
            model=model,
            data=data
        )
    
        # Save results
        epoch_result = get_results(
            epoch=epoch,
            train_loss=train_loss,
            test_loss=test_loss,
            evaluation_results=evaluation_results,
            bootstrap_id=bootstrap_id,
            log_every_n_epochs=10
        )
        results.append(epoch_result)
# Out:
# Processing bootstrap dataset ix=0...
# /home/eucollab/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Epoch 10, train loss: 0.0043, test loss: 0.0919, precision@k: 0.0678, recall@k: 0.2132, MAP@k: 0.1132, MRR@k: 0.1787, NDCG@k: 0.1598, HitRate@k: 0.3483
# Epoch 20, train loss: 0.0037, test loss: 0.0914, precision@k: 0.0702, recall@k: 0.2239, MAP@k: 0.1188, MRR@k: 0.1856, NDCG@k: 0.1670, HitRate@k: 0.3614
# Epoch 30, train loss: 0.0032, test loss: 0.0910, precision@k: 0.0703, recall@k: 0.2248, MAP@k: 0.1203, MRR@k: 0.1880, NDCG@k: 0.1685, HitRate@k: 0.3635
# Epoch 40, train loss: 0.0032, test loss: 0.0908, precision@k: 0.0703, recall@k: 0.2252, MAP@k: 0.1201, MRR@k: 0.1876, NDCG@k: 0.1685, HitRate@k: 0.3636
# Epoch 50, train loss: 0.0029, test loss: 0.0908, precision@k: 0.0703, recall@k: 0.2252, MAP@k: 0.1203, MRR@k: 0.1877, NDCG@k: 0.1686, HitRate@k: 0.3634
# Processing bootstrap dataset ix=1...
# Epoch 10, train loss: 0.0038, test loss: 0.0888, precision@k: 0.0673, recall@k: 0.2237, MAP@k: 0.1182, MRR@k: 0.1832, NDCG@k: 0.1657, HitRate@k: 0.3587
# Epoch 20, train loss: 0.0029, test loss: 0.0937, precision@k: 0.0693, recall@k: 0.2275, MAP@k: 0.1205, MRR@k: 0.1869, NDCG@k: 0.1689, HitRate@k: 0.3647
# Epoch 30, train loss: 0.0028, test loss: 0.0936, precision@k: 0.0695, recall@k: 0.2291, MAP@k: 0.1215, MRR@k: 0.1889, NDCG@k: 0.1701, HitRate@k: 0.3668
# Epoch 40, train loss: 0.0029, test loss: 0.0935, precision@k: 0.0694, recall@k: 0.2297, MAP@k: 0.1218, MRR@k: 0.1890, NDCG@k: 0.1705, HitRate@k: 0.3680
# Epoch 50, train loss: 0.0028, test loss: 0.0936, precision@k: 0.0694, recall@k: 0.2298, MAP@k: 0.1214, MRR@k: 0.1889, NDCG@k: 0.1703, HitRate@k: 0.3681
# Processing bootstrap dataset ix=2...
# Epoch 10, train loss: 0.0041, test loss: 0.0880, precision@k: 0.0681, recall@k: 0.2189, MAP@k: 0.1194, MRR@k: 0.1859, NDCG@k: 0.1656, HitRate@k: 0.3496
# Epoch 20, train loss: 0.0034, test loss: 0.0892, precision@k: 0.0695, recall@k: 0.2246, MAP@k: 0.1240, MRR@k: 0.1932, NDCG@k: 0.1711, HitRate@k: 0.3580
# Epoch 30, train loss: 0.0033, test loss: 0.0888, precision@k: 0.0697, recall@k: 0.2254, MAP@k: 0.1247, MRR@k: 0.1939, NDCG@k: 0.1718, HitRate@k: 0.3588
# Epoch 40, train loss: 0.0031, test loss: 0.0890, precision@k: 0.0698, recall@k: 0.2259, MAP@k: 0.1252, MRR@k: 0.1958, NDCG@k: 0.1726, HitRate@k: 0.3592
# Epoch 50, train loss: 0.0033, test loss: 0.0891, precision@k: 0.0698, recall@k: 0.2258, MAP@k: 0.1254, MRR@k: 0.1957, NDCG@k: 0.1726, HitRate@k: 0.3589
# Processing bootstrap dataset ix=3...
# Epoch 10, train loss: 0.0041, test loss: 0.0844, precision@k: 0.0673, recall@k: 0.2185, MAP@k: 0.1167, MRR@k: 0.1828, NDCG@k: 0.1636, HitRate@k: 0.3563
# Epoch 20, train loss: 0.0032, test loss: 0.0835, precision@k: 0.0685, recall@k: 0.2245, MAP@k: 0.1207, MRR@k: 0.1894, NDCG@k: 0.1687, HitRate@k: 0.3629
# Epoch 30, train loss: 0.0026, test loss: 0.0829, precision@k: 0.0699, recall@k: 0.2298, MAP@k: 0.1216, MRR@k: 0.1912, NDCG@k: 0.1709, HitRate@k: 0.3693
# Epoch 40, train loss: 0.0027, test loss: 0.0831, precision@k: 0.0700, recall@k: 0.2300, MAP@k: 0.1219, MRR@k: 0.1906, NDCG@k: 0.1710, HitRate@k: 0.3691
# Epoch 50, train loss: 0.0026, test loss: 0.0831, precision@k: 0.0700, recall@k: 0.2300, MAP@k: 0.1221, MRR@k: 0.1913, NDCG@k: 0.1713, HitRate@k: 0.3693
# Processing bootstrap dataset ix=4...
# Epoch 10, train loss: 0.0047, test loss: 0.0931, precision@k: 0.0658, recall@k: 0.2116, MAP@k: 0.1144, MRR@k: 0.1800, NDCG@k: 0.1595, HitRate@k: 0.3424
# Epoch 20, train loss: 0.0036, test loss: 0.0888, precision@k: 0.0683, recall@k: 0.2226, MAP@k: 0.1191, MRR@k: 0.1865, NDCG@k: 0.1664, HitRate@k: 0.3584
# Epoch 30, train loss: 0.0033, test loss: 0.0855, precision@k: 0.0689, recall@k: 0.2252, MAP@k: 0.1213, MRR@k: 0.1895, NDCG@k: 0.1689, HitRate@k: 0.3615
# Epoch 40, train loss: 0.0030, test loss: 0.0843, precision@k: 0.0696, recall@k: 0.2278, MAP@k: 0.1224, MRR@k: 0.1912, NDCG@k: 0.1705, HitRate@k: 0.3647
# Epoch 50, train loss: 0.0028, test loss: 0.0845, precision@k: 0.0699, recall@k: 0.2276, MAP@k: 0.1230, MRR@k: 0.1924, NDCG@k: 0.1712, HitRate@k: 0.3659
# Processing bootstrap dataset ix=5...
# Epoch 10, train loss: 0.0040, test loss: 0.0926, precision@k: 0.0675, recall@k: 0.2164, MAP@k: 0.1166, MRR@k: 0.1828, NDCG@k: 0.1629, HitRate@k: 0.3525
# Epoch 20, train loss: 0.0034, test loss: 0.0966, precision@k: 0.0681, recall@k: 0.2202, MAP@k: 0.1183, MRR@k: 0.1844, NDCG@k: 0.1651, HitRate@k: 0.3548
# Epoch 30, train loss: 0.0034, test loss: 0.0956, precision@k: 0.0685, recall@k: 0.2218, MAP@k: 0.1198, MRR@k: 0.1866, NDCG@k: 0.1668, HitRate@k: 0.3564
# Epoch 40, train loss: 0.0032, test loss: 0.0956, precision@k: 0.0686, recall@k: 0.2222, MAP@k: 0.1201, MRR@k: 0.1868, NDCG@k: 0.1671, HitRate@k: 0.3564
# Epoch 50, train loss: 0.0032, test loss: 0.0956, precision@k: 0.0686, recall@k: 0.2222, MAP@k: 0.1203, MRR@k: 0.1874, NDCG@k: 0.1672, HitRate@k: 0.3565
# Processing bootstrap dataset ix=6...
# Epoch 10, train loss: 0.0042, test loss: 0.0900, precision@k: 0.0666, recall@k: 0.2119, MAP@k: 0.1180, MRR@k: 0.1869, NDCG@k: 0.1631, HitRate@k: 0.3437
# Epoch 20, train loss: 0.0035, test loss: 0.0914, precision@k: 0.0692, recall@k: 0.2203, MAP@k: 0.1225, MRR@k: 0.1903, NDCG@k: 0.1689, HitRate@k: 0.3569
# Epoch 30, train loss: 0.0030, test loss: 0.0898, precision@k: 0.0697, recall@k: 0.2229, MAP@k: 0.1224, MRR@k: 0.1892, NDCG@k: 0.1693, HitRate@k: 0.3586
# Epoch 40, train loss: 0.0030, test loss: 0.0896, precision@k: 0.0697, recall@k: 0.2228, MAP@k: 0.1225, MRR@k: 0.1891, NDCG@k: 0.1694, HitRate@k: 0.3585
# Epoch 50, train loss: 0.0032, test loss: 0.0896, precision@k: 0.0697, recall@k: 0.2228, MAP@k: 0.1226, MRR@k: 0.1892, NDCG@k: 0.1696, HitRate@k: 0.3585
# Processing bootstrap dataset ix=7...
# Epoch 10, train loss: 0.0039, test loss: 0.0869, precision@k: 0.0679, recall@k: 0.2176, MAP@k: 0.1194, MRR@k: 0.1864, NDCG@k: 0.1655, HitRate@k: 0.3533
# Epoch 20, train loss: 0.0036, test loss: 0.0852, precision@k: 0.0700, recall@k: 0.2250, MAP@k: 0.1222, MRR@k: 0.1915, NDCG@k: 0.1701, HitRate@k: 0.3630
# Epoch 30, train loss: 0.0029, test loss: 0.0831, precision@k: 0.0704, recall@k: 0.2276, MAP@k: 0.1235, MRR@k: 0.1939, NDCG@k: 0.1719, HitRate@k: 0.3658
# Epoch 40, train loss: 0.0028, test loss: 0.0818, precision@k: 0.0710, recall@k: 0.2308, MAP@k: 0.1248, MRR@k: 0.1943, NDCG@k: 0.1735, HitRate@k: 0.3700
# Epoch 50, train loss: 0.0029, test loss: 0.0821, precision@k: 0.0708, recall@k: 0.2304, MAP@k: 0.1242, MRR@k: 0.1943, NDCG@k: 0.1730, HitRate@k: 0.3683
# Processing bootstrap dataset ix=8...
# Epoch 10, train loss: 0.0042, test loss: 0.0866, precision@k: 0.0659, recall@k: 0.2087, MAP@k: 0.1125, MRR@k: 0.1781, NDCG@k: 0.1576, HitRate@k: 0.3435
# Epoch 20, train loss: 0.0035, test loss: 0.0843, precision@k: 0.0663, recall@k: 0.2126, MAP@k: 0.1159, MRR@k: 0.1840, NDCG@k: 0.1615, HitRate@k: 0.3471
# Epoch 30, train loss: 0.0030, test loss: 0.0827, precision@k: 0.0684, recall@k: 0.2199, MAP@k: 0.1187, MRR@k: 0.1877, NDCG@k: 0.1660, HitRate@k: 0.3576
# Epoch 40, train loss: 0.0027, test loss: 0.0833, precision@k: 0.0677, recall@k: 0.2190, MAP@k: 0.1191, MRR@k: 0.1875, NDCG@k: 0.1658, HitRate@k: 0.3534
# Epoch 50, train loss: 0.0028, test loss: 0.0835, precision@k: 0.0680, recall@k: 0.2201, MAP@k: 0.1204, MRR@k: 0.1893, NDCG@k: 0.1672, HitRate@k: 0.3556
# Processing bootstrap dataset ix=9...
# Epoch 10, train loss: 0.0043, test loss: 0.0917, precision@k: 0.0677, recall@k: 0.2148, MAP@k: 0.1170, MRR@k: 0.1849, NDCG@k: 0.1632, HitRate@k: 0.3503
# Epoch 20, train loss: 0.0036, test loss: 0.0870, precision@k: 0.0700, recall@k: 0.2242, MAP@k: 0.1212, MRR@k: 0.1897, NDCG@k: 0.1689, HitRate@k: 0.3599
# Epoch 40, train loss: 0.0030, test loss: 0.0860, precision@k: 0.0700, recall@k: 0.2265, MAP@k: 0.1227, MRR@k: 0.1937, NDCG@k: 0.1709, HitRate@k: 0.3631
# Epoch 50, train loss: 0.0031, test loss: 0.0861, precision@k: 0.0702, recall@k: 0.2270, MAP@k: 0.1229, MRR@k: 0.1930, NDCG@k: 0.1711, HitRate@k: 0.3638

# %% [markdown]
# ### Model evaluation

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(f'../results/results_Model_bootstrapped_{model_name}.csv', index=False)

# %%
# Generate loss curve
# Train loss
sns.lineplot(data=results_df, x='Epoch', y='Train Loss')
# Test loss
sns.lineplot(data=results_df, x='Epoch', y='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss curve')
plt.yscale('log')
plt.show()

# %%
results_df['HitRate@k'].median()
# Out:
# 0.35850808024406433

# %%
# Generate evaluation metrics plot
sns.lineplot(data=results_df, x='Epoch', y='Precision@k')
sns.lineplot(data=results_df, x='Epoch', y='Recall@k')
sns.lineplot(data=results_df, x='Epoch', y='MAP@k')
sns.lineplot(data=results_df, x='Epoch', y='MRR@k')
sns.lineplot(data=results_df, x='Epoch', y='NDCG@k')
sns.lineplot(data=results_df, x='Epoch', y='HitRate@k')
plt.xlabel('Epoch')
plt.ylabel('Performance')
plt.title('Performance metrics')
plt.show()
