# %% [markdown]
# # Collaboration recommender system 2.0

# %% [markdown]
# ## **Setting up environment**
#
# ---

# %% [markdown]
# ### **Package installation**
#
# Installing `torch` and `torch_geometric` libraries.

# %%
import torch
import os
os.environ['TORCH'] = torch.__version__
print(os.environ['TORCH'])
# Out:
# 2.4.0+cpu

# %% [markdown]
# ### **Loading libraries**

# %%
import sys
import os

sys.path.insert(0, os.path.abspath("../.."))

# PyTorch imports
from torch import Tensor
import torch.nn.functional as F
from torch.nn import Embedding

# PyTorch Geometric imports
import torch_geometric
import torch_geometric.transforms as T
from torch_geometric import EdgeIndex
from torch_geometric.loader import LinkNeighborLoader, NeighborLoader
from torch_geometric.nn import SAGEConv, HeteroConv, to_hetero, MIPSKNNIndex, Linear
from torch_geometric.data import HeteroData, Batch
from torch_geometric.nn.models.lightgcn import BPRLoss
from torch_geometric.utils import structured_negative_sampling
from torch_geometric.metrics import (
    LinkPredPrecision,
    LinkPredRecall,
    LinkPredMAP,
    LinkPredMRR,
    LinkPredNDCG
    )


# Other imports
import io
import datetime
import math
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
from box import Box
from tqdm import tqdm
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from util.postgres import create_sqlalchemy_engine, query

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(torch.__version__)
print(torch_geometric.__version__)
print(f"Device: '{device}'")
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# 2.4.0+cpu
# 2.7.0
# Device: 'cpu'

# %% [markdown]
# ### **Global variables**

# %%
# -------------------- GLOBAL VARIABLES --------------------
PATH_TO_CONFIG_FILE = '../../config.yaml'

# -------------------- LOAD CONFIGURATION --------------------
# Load the configuration file
config = Box.from_yaml(filename=PATH_TO_CONFIG_FILE)

num_recommendations = 10    # Number of recommendations
num_train = 0.8             # Percentage of data used for training
learning_rate = 1e-2        # Learning rate
num_epochs = 20            # Number of epochs
hidden_channels = 128       # Number of hidden channels

target_edge_type = ('author', 'co_authors', 'author')
target_node_type = 'author'

pg_engine = create_sqlalchemy_engine(
    username=config.POSTGRES.USERNAME,
    password=config.POSTGRES.PASSWORD,
    host=config.POSTGRES.HOST,
    port=config.POSTGRES.PORT,
    database=config.POSTGRES.DATABASE,
    schema=config.POSTGRES.SCHEMA
)
batch_size = 10000

# %% [markdown]
# ## **Data preparation**
#
# ---

# %% [markdown]
# ### **Loading data**
#
# When loading the data, we take into account only the articles, where at least one author comes from the EUTOPIA

# %%
# %%time
# Get all authors data and value metrics about their collaboration
author_query = f"""
SELECT *
FROM g_eucoht_node_author
"""
with pg_engine.connect() as conn:
    author_df = query(conn=conn, query_str=author_query)

conn.close()
author_df.head(5)
# Out:
# CPU times: user 62.2 ms, sys: 8.99 ms, total: 71.1 ms
# Wall time: 158 ms
#              author_id  dummy_feature
# 0  0000-0001-6379-2381              1
# 1  0000-0001-7809-8050              1
# 2  0000-0001-8367-5465              1
# 3  0000-0001-8606-6825              1
# 4  0000-0001-8718-9819              1

# %%
# %%time
# Get all authors data and value metrics about their collaboration
published_query = f"""
SELECT *
FROM g_eucoht_edge_publishes
"""
with pg_engine.connect() as conn:
    published_df = query(conn=conn, query_str=published_query)

conn.close()
published_df.head(5)
# Out:
# CPU times: user 972 ms, sys: 201 ms, total: 1.17 s
# Wall time: 1.33 s
#              author_id              article_id      time
# 0          23037324500              0013330732  20180206
# 1           6507696573              0013330732  20180206
# 2  0000-0003-4842-5676  10.1002/aenm.201301688  20140101
# 3          14822457300  10.1002/cmdc.201402459  20141217
# 4  0000-0001-7809-8050  10.1002/cplu.201402054  20140101

# %%
# %%time
# Get all authors data and value metrics about their collaboration
coauthored_query = f"""
SELECT *
FROM g_eucoht_edge_co_authors
"""
with pg_engine.connect() as conn:
    coauthored_df = query(conn=conn, query_str=coauthored_query)

conn.close()
coauthored_df.head(5)
# Out:
# CPU times: user 138 ms, sys: 22.7 ms, total: 161 ms
# Wall time: 201 ms
#              author_id         co_author_id      time  \
# 0  0000-0001-8367-5465  0000-0001-9448-789X  20050101
# 1  0000-0001-9448-789X  0000-0001-8367-5465  20050101
# 2  0000-0003-3517-3780           6506321882  20120101
# 3          10040417200           8221262000  20090101
# 4          10040997700          18233779900  20091101
#
#    eutopia_collaboration_count
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
# %%time
with pg_engine.raw_connection().cursor() as cur:
    article_query = f"""
    SELECT article_id,
           article_citation_normalized_count,
           is_eutopia_collaboration,
           collaboration_novelty_index,
           article_embedding
    FROM g_eucoht_node_article
    """
    cur.execute(article_query)
    # Initialize the Polars DataFrame
    article_df_polars: pl.DataFrame = pl.DataFrame()
    ix = 0
    # Fetch in chunks
    while True:
        rows = cur.fetchmany(size=batch_size)
        if not rows:
            break
        # Append the rows to the Polars DataFrame
        df_chunk = pl.DataFrame(rows, schema=[
            "article_id", 
            "article_citation_normalized_count",
            "is_eutopia_collaboration",
            "collaboration_novelty_index",
            "article_embedding"
        ], orient="row")
    
        # Concatenate chunk with the master DataFrame
        article_df_polars = pl.concat([article_df_polars, df_chunk], how="vertical")
        print(f"Rows fetched {batch_size} for batch {ix}")
        ix += 1

article_df = article_df_polars.to_pandas()
article_df.head(5)
# Out:
# Rows fetched 10000 for batch 0
# Rows fetched 10000 for batch 1
# Rows fetched 10000 for batch 2
# Rows fetched 10000 for batch 3
# Rows fetched 10000 for batch 4
# Rows fetched 10000 for batch 5
# CPU times: user 33.5 s, sys: 9.32 s, total: 42.8 s
# Wall time: 1min 2s
#     article_id article_citation_normalized_count  is_eutopia_collaboration  \
# 0  84865405594                             20.42                         0
# 1  84880929267                              1.37                         0
# 2  77952382135                              4.29                         0
# 3  77954866153                              6.23                         0
# 4  85030783799                              1.42                         0
#
#    collaboration_novelty_index  \
# 0                     0.861111
# 1                     0.500070
# 2                     3.000000
# 3                     0.770833
# 4                     2.000000
#
#                                    article_embedding
# 0  [0.004589761607348919, 0.02756412886083126, -0...
# 1  [0.010607256554067135, 0.027150079607963562, -...
# 2  [-0.006951452698558569, -0.0008734843577258289...
# 3  [0.005069693550467491, 0.007222142070531845, -...
# 4  [-0.01370143610984087, 0.01628061570227146, 0....

# %% [markdown]
# ### Contiguous unique identifier for node: **author**

# %%
# Author: Map each unique MD5 hash to a contiguous unique integer ID
unique_authors = author_df['author_id'].unique()
author_id_map = {author: i for i, author in enumerate(unique_authors)}
author_sid_map = {y: x for x, y in author_id_map.items()}
# ---> Adjust all dataframes
author_df['author_node_id'] = author_df['author_id'].map(author_id_map)
published_df['author_node_id'] = published_df['author_id'].map(author_id_map)
coauthored_df['author_node_id'] = coauthored_df['author_id'].map(author_id_map)
coauthored_df['co_author_node_id'] = coauthored_df['co_author_id'].map(author_id_map)

# %% [markdown]
# ### Contiguous unique identifier for node: **article**

# %%
# Article: Map each unique MD5 hash to a contiguous unique integer ID
unique_articles = published_df['article_id'].unique()
article_id_map = {article: i for i, article in enumerate(unique_articles)}
article_sid_map = {y: x for x, y in article_id_map.items()}
# ---> Adjust all dataframes
article_df['article_node_id'] = article_df['article_id'].map(article_id_map)
published_df['article_node_id'] = published_df['article_id'].map(article_id_map)

# %% [markdown]
# ## **Heterogeneous graph creation**
# First of all, we prepare the node features for articles. We first sort the article dataframe by node ID. We know that we have unique values in the article dataframe, i.e. one row per article and we can just sort it. Otherwise, we would need to create a unique mapping between article features and articles themselves. The sorting needs to match the node index that we will create later. After that, we also need to set up correct type (specifically, convert Pandas Int64 to int64, but we go for the lazy version and just convert all features to float64). At last, we exclude the `ARTICLE_SID` and `ARTICLE_NODE_ID` columns, because Torch can't work with strings.
#
# **TODO:**
# - Think about only including "valuable" partnerships/edges.

# %% [markdown]
# ### Matrix X for node: **article**

# %%
# Article X
# Sort article dataframe
sorted_article_df = article_df.sort_values(by='article_node_id')
article_x_columns = list(filter(lambda x: x not in ('article_id', 'article_node_id', 'article_embedding'), sorted_article_df.columns))

# Convert EMBEDDING_TENSOR_DATA to proper format
embedding_tensor = np.stack(sorted_article_df['article_embedding'].values)
embedding_tensor = torch.tensor(embedding_tensor, dtype=torch.float)

# Convert types
article_x = sorted_article_df[article_x_columns].astype('float32').values

# Append embedding_tensor to article_x
article_x = np.concatenate((article_x, embedding_tensor), axis=1)

# Normalize X using std scaler
article_x = StandardScaler().fit_transform(article_x)

# %% [markdown]
# ### Matrix X for node: **author**

# %%
# Author X
# Sort author dataframe
sorted_author_df = author_df.sort_values(by='author_node_id')
# Exclude columns AUTHOR_SID, AUTHOR_NODE_ID
author_x_columns = list(filter(lambda x: x not in ('author_id', 'author_node_id'), sorted_author_df.columns))
# Convert types
author_x = sorted_author_df[author_x_columns].astype('float32').values

# Normalize X using std scaler
author_x = StandardScaler().fit_transform(author_x)

# %% [markdown]
# ### Edge index for edge: **(author, publishes, article)**

# %%
# Add edge index: for edges corresponding to authors publishing articles (author to article connection)
author_node_ids = torch.from_numpy(published_df['author_node_id'].values)
article_node_ids = torch.from_numpy(published_df['article_node_id'].values)
edge_index_publishes = torch.stack([author_node_ids, article_node_ids], dim=0)
edge_time_publishes = torch.from_numpy(np.array(published_df['time'].values.astype('int64')))

# %% [markdown]
# ### Edge index for edge: **(author, co_authors, author)**

# %%
# Add edge index: for edges corresponding to authors co-authoring articles (author to author connection)
author_node_ids = torch.from_numpy(coauthored_df['author_node_id'].values)
coauthor_node_ids = torch.from_numpy(coauthored_df['co_author_node_id'].values)
edge_index_co_authors = torch.stack([author_node_ids, coauthor_node_ids], dim=0)
edge_time_co_authors = torch.from_numpy(np.array(coauthored_df['time'].values.astype('int64')))

# %% [markdown]
# ### Data object

# %% [markdown]
# After generating the initial node feature Numpy array, we create an instance of `HeteroData` class with two types of nodes corresponding to authors and articles and an edge denoting authors publishing articles.
#
# *Note: We also need to make sure to add the reverse edges from authors to aritcles in order to let a GNN be able to pass messages in both directions. We can leverage the `T.ToUndirected()` transform for this from PyG.*

# %%
data = HeteroData()

# Save node indices:
data["article"].node_id = torch.arange(len(unique_articles))
data["author"].node_id = torch.arange(len(unique_authors))
# Add edge 'published'
data["author", "publishes", "article"].edge_index = edge_index_publishes
data["author", "publishes", "article"].time = edge_time_publishes
# Add edge 'co_authors'
data[('author', 'co_authors', 'author')].edge_index = edge_index_co_authors
data[('author', 'co_authors', 'author')].time = edge_time_co_authors

# Set X for article
data["article"].x = torch.from_numpy(article_x)
# Set X for author
data["author"].x = torch.from_numpy(author_x)

# Reverse edges
data = T.ToUndirected(reduce='min')(data)
data
# Out:
# HeteroData(
#   article={
#     node_id=[55076],
#     x=[55076, 771],
#   },
#   author={
#     node_id=[7734],
#     x=[7734, 1],
#   },
#   (author, publishes, article)={
#     edge_index=[2, 124874],
#     time=[124874],
#   },
#   (author, co_authors, author)={
#     edge_index=[2, 28210],
#     time=[28210],
#   },
#   (article, rev_publishes, author)={
#     edge_index=[2, 124874],
#     time=[124874],
#   }
# )

# %% [markdown]
# ## Heterogeneous graph batching

# %% [markdown]
# ###  Split data to train, test

# %%
edge_types = data.metadata()[1]

time = data[target_edge_type].time
perm = time.argsort()
# Find minimum time in `co_authors` edge that still resides in test set
test_min_time = time[perm[int(num_train * perm.numel()):]].min()

for edge_type in edge_types:
  # Define the training dataset for all edge types
  time = data[edge_type].time
  data[edge_type].train_mask = time < test_min_time
  data[edge_type].train_edge_index = data[edge_type].edge_index[:, data[edge_type].train_mask]
  data[edge_type].train_edge_time = time[data[edge_type].train_mask]

data.train_edge_index_dict = {edge_type: data[edge_type].train_edge_index for edge_type in edge_types}

# Add test dataset for `co_authors` edge type
data[target_edge_type].test_mask = data[target_edge_type].time >= test_min_time
data[target_edge_type].test_pos_edge_index = data[target_edge_type].edge_index[:, data[target_edge_type].test_mask]
data[target_edge_type].test_edge_time = data[target_edge_type].time[data[target_edge_type].test_mask]


# Negative sampling
test_neg_edge_index_i, test_neg_edge_index_j, test_neg_edge_index_k = structured_negative_sampling(
    edge_index=data[target_edge_type].test_pos_edge_index,
    num_nodes=data[target_node_type].num_nodes)
test_neg_edge_index = torch.stack([test_neg_edge_index_i, test_neg_edge_index_k], dim=0)
# Add negative samples to test data
data[target_edge_type].test_neg_edge_index = test_neg_edge_index

# %%
data
# Out:
# HeteroData(
#   train_edge_index_dict={
#     (author, publishes, article)=[2, 81095],
#     (author, co_authors, author)=[2, 22548],
#     (article, rev_publishes, author)=[2, 81095],
#   },
#   article={
#     node_id=[55076],
#     x=[55076, 771],
#   },
#   author={
#     node_id=[7734],
#     x=[7734, 1],
#   },
#   (author, publishes, article)={
#     edge_index=[2, 124874],
#     time=[124874],
#     train_mask=[124874],
#     train_edge_index=[2, 81095],
#     train_edge_time=[81095],
#   },
#   (author, co_authors, author)={
#     edge_index=[2, 28210],
#     time=[28210],
#     train_mask=[28210],
#     train_edge_index=[2, 22548],
#     train_edge_time=[22548],
#     test_mask=[28210],
#     test_pos_edge_index=[2, 5662],
#     test_edge_time=[5662],
#     test_neg_edge_index=[2, 5662],
#   },
#   (article, rev_publishes, author)={
#     edge_index=[2, 124874],
#     time=[124874],
#     train_mask=[124874],
#     train_edge_index=[2, 81095],
#     train_edge_time=[81095],
#   }
# )

# %% [markdown]
# ### Data loader (mini-batching)
#
# After splitting the data, we need to take into account that we are dealing with very large graphs. A simple load of data to GPU will already return `CUDA out of memory` exception. Hence, we use mini-batching to appropriately split the edges (regardless if we are in training, testing or validation phase). This process will separate the large graph into multiple smaller graphs and process them independently, thus fixing the out-of-memory exceptions.

# %% [markdown]
# ## Model training
#
#
# ---

# %% [markdown]
# ### Model definition
#
# Our model consists of two parts, first we must encode our nodes using the message passing algorithm exploiting both (author, co-authors, author) and (author, publishes, article) edges and corresponding node features. The second part decodes the edges that the model outputs as its prediction using two simple, fully-connected, linear layers.
#
# **TODO:**
# - Promote EUTOPIA-an collaborations or even restrict to EUTOPIA-an collaborations.

# %%
##%%
from typing import Optional, Union

import torch
import torch.nn.functional as F
from torch import Tensor
from torch.nn import Embedding, ModuleList
from torch.nn.modules.loss import _Loss

from torch_geometric.nn.conv import GATv2Conv, TransformerConv
from torch_geometric.typing import Adj, OptTensor
from torch_geometric.utils import is_sparse, to_edge_index
from torch_geometric.nn.models.lightgcn import BPRLoss

class Encoder(torch.nn.Module):
    def __init__(self, 
                 hidden_channels: int,
                 num_layers: int,
                 include_linear_layers: bool,
                 include_activation_layers: bool
                ):
        super().__init__()

        self.num_layers = num_layers
        self.include_linear_layers = include_linear_layers
        self.include_activation_layers = include_activation_layers
        self.alpha = 1. / (self.num_layers + 1) # not used ATM

        # Number of attention heads
        num_attention_heads = 2
        
        # # Initialize the convolutional layers
        self.conv_layers = ModuleList([
            # GATv2Conv(
            #     in_channels=(-1, -1), 
            #     out_channels=hidden_channels, 
            #     add_self_loops=False, 
            #     negative_slope=0.2,
            #     dropout=0.5
            # )
            TransformerConv(
                in_channels=(-1, -1), 
                out_channels=hidden_channels,
                heads=num_attention_heads,
                dropout=0.2
            )
            
            for i in range(self.num_layers)
        ])

        # Linear layers
        self.lin_layers = ModuleList([
            Linear(-1, hidden_channels * num_attention_heads) for i in range(self.num_layers)
            
        ])

        # Initialize batch norm layers
        self.bn_layers = ModuleList([
            torch.nn.BatchNorm1d(hidden_channels * num_attention_heads) for i in range(self.num_layers)
            ])

    def forward(self, x, edge_index):
        # Activate layers
        for i in range(self.num_layers):
            x = self.conv_layers[i](x, edge_index)
            # Linear layer (skip connection instead of self loops)
            if self.include_linear_layers:
                x += self.lin_layers[i](x)
            x = self.bn_layers[i](x)
            # Activation layer
            if self.include_activation_layers and i < self.num_layers - 1:
                x = x.relu()

        return x


class Decoder(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, z, edge_label_index):
        out_src = z[edge_label_index[0]]
        out_dst = z[edge_label_index[1]]

        # Calculate the dot product
        return (out_src * out_dst).sum(dim=-1)

class CollaborationRecommender(torch.nn.Module):
    def __init__(self,
                 hidden_channels: int,
                 num_layers: int,
                 include_linear_layers: bool,
                 include_activation_layers: bool,
                 k: int,
                 alpha: Optional[Union[float, Tensor]] = None):
        super().__init__()

        self.hidden_channels = hidden_channels
        self.k = k

        self.encoder = Encoder(
            hidden_channels=hidden_channels,
            num_layers=num_layers,
            include_linear_layers=include_linear_layers,
            include_activation_layers=include_activation_layers
        )
        self.encoder = to_hetero(self.encoder, (['article', 'author'],
                                                 [('author', 'publishes', 'article'),
                                                    ('author', 'co_authors', 'author'),
                                                    ('article', 'rev_publishes', 'author')]), aggr='sum')
        self.decoder = Decoder()


    def forward(self,
                x_dict,
                edge_index_dict,
                edge_label_index: OptTensor = None):

        # Encode authors
        z_dict = self.encoder(x_dict, edge_index_dict)
        z = z_dict['author']
        # Decode edges
        return self.decoder(z, edge_label_index)

    def recommend(self,
                  x_dict,
                  edge_index_dict,
                  author_sid: str,
                  k: int = 10):

        # Get all embeddings
        out_src = out_dst = self.encoder(x_dict, edge_index_dict)

        # Get the author id
        author_id = author_id_map[author_sid]
        # Get the author embedding
        out_src = out_src[author_id]

        # Calculate the dot product
        pred = out_src @ out_dst.t()
        # Get the top k recommendations
        top_index = pred.topk(k, dim=-1, sorted=True).indices

        # Decode top k recommendations to author SIDs
        top_author_sids = [author_sid_map[int(i)] for i in top_index]

        return top_author_sids


    def recommendation_loss(self,
                            x_dict,
                            edge_index_dict,
                            pos_edge_rank,
                            neg_edge_rank,
                            node_id: Optional[Tensor] = None,
                            lambda_reg: float = 1e-4):
        loss_fn = BPRLoss(lambda_reg)
        # Get the embedding
        z_dict = self.encoder(x_dict, edge_index_dict)
        emb = z_dict['author']
        # Get the loss
        emb = emb if node_id is None else emb[node_id]
        return loss_fn(pos_edge_rank, neg_edge_rank, emb)

# %% [markdown]
# ### Helper functions for training and evaluation
#
# Our model is then trained through a number of epochs, where in each epoch we perform mini-batching to avoid memory issues on GPU.

# %%
import pytest
from torch_geometric.metrics.link_pred import LinkPredMetric
class LinkPredHitRate(LinkPredMetric):
    higher_is_better: bool = True

    def _compute(self, pred_isin_mat: Tensor, y_count: Tensor) -> Tensor:
        return pred_isin_mat.sum(dim=-1) >= 1

def test_hit_rate():
    pred_mat = torch.tensor([[1, 0], [1, 2], [0, 2], [0, 1]])
    edge_label_index = torch.tensor([[0, 0, 2, 2, 3], [0, 1, 2, 1, 2]])

    metric = LinkPredHitRate(k=2)
    metric.update(pred_mat, edge_label_index)
    result = metric.compute()

    assert result == pytest.approx((2) / 3)

test_hit_rate()

def train():
    model.train()
    # Fetch existing graph edges as positive samples
    pos_edge_index = data[target_edge_type].train_edge_index
    # Perform structured negative sampling, meaning that for every positive sample,
    # there will be another negative sample at the same index/position
    # - this structure is expected in BPR loss calculation
    neg_edge_index_i, neg_edge_index_j, neg_edge_index_k = structured_negative_sampling(
        edge_index=pos_edge_index,
        num_nodes=data[target_node_type].num_nodes)
    # Structure negative sampling returns both positive and negative edges, so
    # we need to concatenate appropriate nodes to get the negative edges
    neg_edge_index = torch.stack([neg_edge_index_i, neg_edge_index_k], dim=0)

    optimizer.zero_grad()

    # Concatenate edge label indices into a single edge label index
    edge_label_index = torch.cat([
        pos_edge_index,
        neg_edge_index,
    ], dim=1)

    pos_edge_rank, neg_edge_rank = model(x_dict=data.x_dict,
                                         edge_index_dict=data.train_edge_index_dict,
                                         edge_label_index=edge_label_index).chunk(2)

    # Calculate BPR loss
    loss = model.recommendation_loss(x_dict=data.x_dict,
                                     edge_index_dict=data.train_edge_index_dict,
                                     pos_edge_rank=pos_edge_rank,
                                     neg_edge_rank=neg_edge_rank,
                                     node_id=edge_label_index.unique())

    loss.backward()
    optimizer.step()

    total_loss = float(loss) * pos_edge_rank.numel()
    total_examples = pos_edge_rank.numel()

    # Cleanup
    del pos_edge_rank, neg_edge_rank
    torch.cuda.empty_cache()

    return total_loss / total_examples


@torch.no_grad()
def test():
    model.eval()

    pos_edge_index = data[target_edge_type].test_pos_edge_index
    neg_edge_index = data[target_edge_type].test_neg_edge_index

    # Concatenate edge label indices into a single edge label index
    edge_label_index = torch.cat([
        pos_edge_index,
        neg_edge_index,
    ], dim=1)

    # We encode the training edge index to get the embeddings based on the training graph
    # structure and then use those embeddings to predict unseen edges
    # TODO: Check if this makes sense
    pos_edge_rank, neg_edge_rank = model(x_dict=data.x_dict,
                                         edge_index_dict=data.train_edge_index_dict,
                                         edge_label_index=edge_label_index).chunk(2)

    # Calculate BPR loss
    loss = model.recommendation_loss(x_dict=data.x_dict,
                                     edge_index_dict=data.train_edge_index_dict,
                                     pos_edge_rank=pos_edge_rank,
                                     neg_edge_rank=neg_edge_rank,
                                     node_id=edge_label_index.unique())

    total_loss = float(loss) * pos_edge_rank.numel()
    total_examples = pos_edge_rank.numel()

    # Cleanup
    del pos_edge_rank, neg_edge_rank
    torch.cuda.empty_cache()

    return total_loss / total_examples

@torch.no_grad()
def evaluate(k:int=20):
    model.eval()
    z_dict = model.encoder(data.x_dict, data.train_edge_index_dict)
    embs = z_dict[target_node_type].to(device)

    result = {
        'precision@k': LinkPredPrecision(k=k).to(device),
        'recall@k': LinkPredRecall(k=k).to(device),
        'map@k': LinkPredMAP(k=k).to(device),
        'mrr@k': LinkPredMRR(k=k).to(device),
        'ndcg@k': LinkPredNDCG(k=k).to(device),
        'hit_rate@k': LinkPredHitRate(k=k).to(device)
        }

    # Calculate distance between embeddings
    logits = embs @ embs.T

    # Exclude training edges
    logits[data[target_edge_type].train_edge_index[0], data[target_edge_type].train_edge_index[1]] = float('-inf')

    # Gather ground truth data
    ground_truth = data[target_edge_type].test_pos_edge_index

    # Get top-k recommendations for each node
    top_k_index = torch.topk(logits, k=k, dim=1).indices

    # Update performance metrics
    for metric in result.keys():
      result[metric].update(
          pred_index_mat=top_k_index,
          edge_label_index=ground_truth)

    # Cleanup
    del embs, logits, ground_truth, top_k_index
    torch.cuda.empty_cache()

    return result

# %% [markdown]
# ### Training the model

# %%
# Initialize the model
model = CollaborationRecommender(
                     hidden_channels=32,
                     num_layers=3,
                     include_linear_layers=False,
                     include_activation_layers=False,
                     k=num_recommendations
                     ).to(device)

# Transfer to device
data = data.to(device)
optimizer = torch.optim.Adam(params=model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=0.5, patience=3, verbose=True)

results = []
for epoch in range(1,  100 + 1):
    train_loss = train()
    test_loss = test()
    scheduler.step(test_loss)
    eval_result = evaluate(k=num_recommendations)

    # Save results
    epoch_result = {
        'epoch': epoch  ,
        'train_loss_bpr': train_loss,
        'test_loss_bpr': test_loss,
        'precision@k': eval_result['precision@k'].compute(),
        'recall@k': eval_result['recall@k'].compute(),
        'map@k': eval_result['map@k'].compute(),
        'mrr@k': eval_result['mrr@k'].compute(),
        'ndcg@k': eval_result['ndcg@k'].compute(),
        'hit_rate@k': eval_result['hit_rate@k'].compute()
    }
    print(f'learning rate: {scheduler.get_last_lr()}')
    results.append(epoch_result)

    # Log results
    if epoch % 1 == 0:
        # Log model performance
        formatted_str = ', '.join([f'{key}: {epoch_result[key]:.4f}' for key in epoch_result.keys()])
        print(formatted_str)


results = pd.DataFrame(results)
# Out:
# learning rate: [0.001]
# epoch: 1.0000, train_loss_bpr: 0.0685, test_loss_bpr: 6.6141, precision@k: 0.0088, recall@k: 0.0083, map@k: 0.0085, mrr@k: 0.0198, ndcg@k: 0.0123, hit_rate@k: 0.0284
# learning rate: [0.001]
# epoch: 2.0000, train_loss_bpr: 0.0599, test_loss_bpr: 5.5227, precision@k: 0.0125, recall@k: 0.0154, map@k: 0.0114, mrr@k: 0.0249, ndcg@k: 0.0172, hit_rate@k: 0.0409
# learning rate: [0.001]
# epoch: 3.0000, train_loss_bpr: 0.0379, test_loss_bpr: 4.5861, precision@k: 0.0155, recall@k: 0.0198, map@k: 0.0145, mrr@k: 0.0282, ndcg@k: 0.0213, hit_rate@k: 0.0492
# learning rate: [0.001]
# epoch: 4.0000, train_loss_bpr: 0.0355, test_loss_bpr: 3.8926, precision@k: 0.0160, recall@k: 0.0192, map@k: 0.0146, mrr@k: 0.0284, ndcg@k: 0.0214, hit_rate@k: 0.0509
# learning rate: [0.001]
# epoch: 5.0000, train_loss_bpr: 0.0301, test_loss_bpr: 3.4457, precision@k: 0.0169, recall@k: 0.0231, map@k: 0.0158, mrr@k: 0.0290, ndcg@k: 0.0231, hit_rate@k: 0.0526
# learning rate: [0.001]
# epoch: 6.0000, train_loss_bpr: 0.0241, test_loss_bpr: 3.1799, precision@k: 0.0179, recall@k: 0.0260, map@k: 0.0168, mrr@k: 0.0301, ndcg@k: 0.0247, hit_rate@k: 0.0568
# learning rate: [0.001]
# epoch: 7.0000, train_loss_bpr: 0.0332, test_loss_bpr: 3.0323, precision@k: 0.0194, recall@k: 0.0284, map@k: 0.0185, mrr@k: 0.0307, ndcg@k: 0.0266, hit_rate@k: 0.0609
# learning rate: [0.001]
# epoch: 8.0000, train_loss_bpr: 0.0278, test_loss_bpr: 2.9832, precision@k: 0.0207, recall@k: 0.0305, map@k: 0.0195, mrr@k: 0.0326, ndcg@k: 0.0282, hit_rate@k: 0.0659
# learning rate: [0.001]
# epoch: 9.0000, train_loss_bpr: 0.0234, test_loss_bpr: 2.9258, precision@k: 0.0200, recall@k: 0.0294, map@k: 0.0190, mrr@k: 0.0326, ndcg@k: 0.0276, hit_rate@k: 0.0643
# learning rate: [0.001]
# epoch: 10.0000, train_loss_bpr: 0.0187, test_loss_bpr: 2.8721, precision@k: 0.0205, recall@k: 0.0289, map@k: 0.0192, mrr@k: 0.0339, ndcg@k: 0.0280, hit_rate@k: 0.0668
# learning rate: [0.001]
# epoch: 11.0000, train_loss_bpr: 0.0217, test_loss_bpr: 2.8110, precision@k: 0.0207, recall@k: 0.0269, map@k: 0.0194, mrr@k: 0.0348, ndcg@k: 0.0280, hit_rate@k: 0.0643
# learning rate: [0.001]
# epoch: 12.0000, train_loss_bpr: 0.0222, test_loss_bpr: 2.7331, precision@k: 0.0214, recall@k: 0.0287, map@k: 0.0198, mrr@k: 0.0352, ndcg@k: 0.0289, hit_rate@k: 0.0676
# learning rate: [0.001]
# epoch: 13.0000, train_loss_bpr: 0.0160, test_loss_bpr: 2.6705, precision@k: 0.0219, recall@k: 0.0287, map@k: 0.0196, mrr@k: 0.0353, ndcg@k: 0.0289, hit_rate@k: 0.0693
# learning rate: [0.001]
# epoch: 14.0000, train_loss_bpr: 0.0211, test_loss_bpr: 2.5625, precision@k: 0.0229, recall@k: 0.0288, map@k: 0.0201, mrr@k: 0.0377, ndcg@k: 0.0300, hit_rate@k: 0.0735
# learning rate: [0.001]
# epoch: 15.0000, train_loss_bpr: 0.0174, test_loss_bpr: 2.4689, precision@k: 0.0237, recall@k: 0.0318, map@k: 0.0215, mrr@k: 0.0393, ndcg@k: 0.0318, hit_rate@k: 0.0785
# learning rate: [0.001]
# epoch: 16.0000, train_loss_bpr: 0.0270, test_loss_bpr: 2.3842, precision@k: 0.0249, recall@k: 0.0338, map@k: 0.0217, mrr@k: 0.0395, ndcg@k: 0.0327, hit_rate@k: 0.0801
# learning rate: [0.001]
# epoch: 17.0000, train_loss_bpr: 0.0171, test_loss_bpr: 2.3041, precision@k: 0.0247, recall@k: 0.0332, map@k: 0.0215, mrr@k: 0.0388, ndcg@k: 0.0322, hit_rate@k: 0.0801
# learning rate: [0.001]
# epoch: 18.0000, train_loss_bpr: 0.0174, test_loss_bpr: 2.2438, precision@k: 0.0242, recall@k: 0.0331, map@k: 0.0210, mrr@k: 0.0390, ndcg@k: 0.0318, hit_rate@k: 0.0810
# learning rate: [0.001]
# epoch: 19.0000, train_loss_bpr: 0.0183, test_loss_bpr: 2.2172, precision@k: 0.0235, recall@k: 0.0329, map@k: 0.0202, mrr@k: 0.0396, ndcg@k: 0.0312, hit_rate@k: 0.0818
# learning rate: [0.001]
# epoch: 20.0000, train_loss_bpr: 0.0213, test_loss_bpr: 2.1948, precision@k: 0.0230, recall@k: 0.0335, map@k: 0.0204, mrr@k: 0.0384, ndcg@k: 0.0312, hit_rate@k: 0.0793
# learning rate: [0.001]
# epoch: 21.0000, train_loss_bpr: 0.0170, test_loss_bpr: 2.1793, precision@k: 0.0220, recall@k: 0.0334, map@k: 0.0196, mrr@k: 0.0370, ndcg@k: 0.0301, hit_rate@k: 0.0793
# learning rate: [0.001]
# epoch: 22.0000, train_loss_bpr: 0.0201, test_loss_bpr: 2.1614, precision@k: 0.0210, recall@k: 0.0336, map@k: 0.0193, mrr@k: 0.0365, ndcg@k: 0.0297, hit_rate@k: 0.0776
# learning rate: [0.001]
# epoch: 23.0000, train_loss_bpr: 0.0161, test_loss_bpr: 2.1329, precision@k: 0.0205, recall@k: 0.0334, map@k: 0.0185, mrr@k: 0.0338, ndcg@k: 0.0286, hit_rate@k: 0.0751
# learning rate: [0.001]
# epoch: 24.0000, train_loss_bpr: 0.0171, test_loss_bpr: 2.1136, precision@k: 0.0199, recall@k: 0.0319, map@k: 0.0182, mrr@k: 0.0345, ndcg@k: 0.0280, hit_rate@k: 0.0751
# learning rate: [0.001]
# epoch: 25.0000, train_loss_bpr: 0.0212, test_loss_bpr: 2.0993, precision@k: 0.0192, recall@k: 0.0315, map@k: 0.0182, mrr@k: 0.0343, ndcg@k: 0.0277, hit_rate@k: 0.0718
# learning rate: [0.001]
# epoch: 26.0000, train_loss_bpr: 0.0140, test_loss_bpr: 2.0784, precision@k: 0.0197, recall@k: 0.0327, map@k: 0.0180, mrr@k: 0.0347, ndcg@k: 0.0281, hit_rate@k: 0.0751
# learning rate: [0.001]
# epoch: 27.0000, train_loss_bpr: 0.0161, test_loss_bpr: 2.0512, precision@k: 0.0200, recall@k: 0.0336, map@k: 0.0182, mrr@k: 0.0348, ndcg@k: 0.0284, hit_rate@k: 0.0768
# learning rate: [0.001]
# epoch: 28.0000, train_loss_bpr: 0.0117, test_loss_bpr: 2.0310, precision@k: 0.0199, recall@k: 0.0339, map@k: 0.0180, mrr@k: 0.0338, ndcg@k: 0.0282, hit_rate@k: 0.0768
# learning rate: [0.001]
# epoch: 29.0000, train_loss_bpr: 0.0197, test_loss_bpr: 2.0135, precision@k: 0.0195, recall@k: 0.0332, map@k: 0.0181, mrr@k: 0.0343, ndcg@k: 0.0281, hit_rate@k: 0.0768
# learning rate: [0.001]
# epoch: 30.0000, train_loss_bpr: 0.0155, test_loss_bpr: 1.9981, precision@k: 0.0195, recall@k: 0.0319, map@k: 0.0179, mrr@k: 0.0343, ndcg@k: 0.0278, hit_rate@k: 0.0760
# learning rate: [0.001]
# epoch: 31.0000, train_loss_bpr: 0.0196, test_loss_bpr: 1.9764, precision@k: 0.0237, recall@k: 0.0352, map@k: 0.0195, mrr@k: 0.0396, ndcg@k: 0.0316, hit_rate@k: 0.0960
# learning rate: [0.001]
# epoch: 32.0000, train_loss_bpr: 0.0165, test_loss_bpr: 1.9604, precision@k: 0.0250, recall@k: 0.0380, map@k: 0.0212, mrr@k: 0.0444, ndcg@k: 0.0343, hit_rate@k: 0.1018
# learning rate: [0.001]
# epoch: 33.0000, train_loss_bpr: 0.0184, test_loss_bpr: 1.9441, precision@k: 0.0260, recall@k: 0.0400, map@k: 0.0211, mrr@k: 0.0449, ndcg@k: 0.0350, hit_rate@k: 0.1052
# learning rate: [0.001]
# epoch: 34.0000, train_loss_bpr: 0.0159, test_loss_bpr: 1.9294, precision@k: 0.0265, recall@k: 0.0398, map@k: 0.0212, mrr@k: 0.0445, ndcg@k: 0.0350, hit_rate@k: 0.1068
# learning rate: [0.001]
# epoch: 35.0000, train_loss_bpr: 0.0180, test_loss_bpr: 1.9309, precision@k: 0.0272, recall@k: 0.0404, map@k: 0.0221, mrr@k: 0.0455, ndcg@k: 0.0359, hit_rate@k: 0.1068
# learning rate: [0.001]
# epoch: 36.0000, train_loss_bpr: 0.0183, test_loss_bpr: 1.9268, precision@k: 0.0274, recall@k: 0.0402, map@k: 0.0225, mrr@k: 0.0457, ndcg@k: 0.0363, hit_rate@k: 0.1060
# learning rate: [0.001]
# epoch: 37.0000, train_loss_bpr: 0.0115, test_loss_bpr: 1.9296, precision@k: 0.0272, recall@k: 0.0401, map@k: 0.0227, mrr@k: 0.0461, ndcg@k: 0.0364, hit_rate@k: 0.1052
# learning rate: [0.001]
# epoch: 38.0000, train_loss_bpr: 0.0157, test_loss_bpr: 1.9331, precision@k: 0.0270, recall@k: 0.0372, map@k: 0.0218, mrr@k: 0.0430, ndcg@k: 0.0347, hit_rate@k: 0.1018
# learning rate: [0.001]
# epoch: 39.0000, train_loss_bpr: 0.0171, test_loss_bpr: 1.9234, precision@k: 0.0235, recall@k: 0.0369, map@k: 0.0214, mrr@k: 0.0399, ndcg@k: 0.0327, hit_rate@k: 0.0843
# learning rate: [0.001]
# epoch: 40.0000, train_loss_bpr: 0.0163, test_loss_bpr: 1.9143, precision@k: 0.0232, recall@k: 0.0364, map@k: 0.0204, mrr@k: 0.0376, ndcg@k: 0.0315, hit_rate@k: 0.0826
# learning rate: [0.001]
# epoch: 41.0000, train_loss_bpr: 0.0184, test_loss_bpr: 1.9021, precision@k: 0.0239, recall@k: 0.0379, map@k: 0.0208, mrr@k: 0.0382, ndcg@k: 0.0323, hit_rate@k: 0.0851
# learning rate: [0.001]
# epoch: 42.0000, train_loss_bpr: 0.0127, test_loss_bpr: 1.8927, precision@k: 0.0239, recall@k: 0.0377, map@k: 0.0208, mrr@k: 0.0390, ndcg@k: 0.0324, hit_rate@k: 0.0851
# learning rate: [0.001]
# epoch: 43.0000, train_loss_bpr: 0.0130, test_loss_bpr: 1.8944, precision@k: 0.0235, recall@k: 0.0375, map@k: 0.0207, mrr@k: 0.0392, ndcg@k: 0.0322, hit_rate@k: 0.0843
# learning rate: [0.001]
# epoch: 44.0000, train_loss_bpr: 0.0107, test_loss_bpr: 1.9050, precision@k: 0.0234, recall@k: 0.0372, map@k: 0.0205, mrr@k: 0.0386, ndcg@k: 0.0319, hit_rate@k: 0.0835
# learning rate: [0.001]
# epoch: 45.0000, train_loss_bpr: 0.0151, test_loss_bpr: 1.9206, precision@k: 0.0230, recall@k: 0.0350, map@k: 0.0199, mrr@k: 0.0375, ndcg@k: 0.0308, hit_rate@k: 0.0810
# learning rate: [0.0005]
# epoch: 46.0000, train_loss_bpr: 0.0148, test_loss_bpr: 1.9389, precision@k: 0.0224, recall@k: 0.0334, map@k: 0.0196, mrr@k: 0.0371, ndcg@k: 0.0302, hit_rate@k: 0.0785
# learning rate: [0.0005]
# epoch: 47.0000, train_loss_bpr: 0.0119, test_loss_bpr: 1.9348, precision@k: 0.0224, recall@k: 0.0327, map@k: 0.0196, mrr@k: 0.0374, ndcg@k: 0.0301, hit_rate@k: 0.0793
# learning rate: [0.0005]
# epoch: 48.0000, train_loss_bpr: 0.0131, test_loss_bpr: 1.9151, precision@k: 0.0229, recall@k: 0.0324, map@k: 0.0202, mrr@k: 0.0379, ndcg@k: 0.0307, hit_rate@k: 0.0801
# learning rate: [0.0005]
# epoch: 49.0000, train_loss_bpr: 0.0114, test_loss_bpr: 1.8987, precision@k: 0.0229, recall@k: 0.0328, map@k: 0.0201, mrr@k: 0.0374, ndcg@k: 0.0306, hit_rate@k: 0.0801
# learning rate: [0.0005]
# epoch: 50.0000, train_loss_bpr: 0.0140, test_loss_bpr: 1.8760, precision@k: 0.0235, recall@k: 0.0336, map@k: 0.0206, mrr@k: 0.0373, ndcg@k: 0.0312, hit_rate@k: 0.0810
# learning rate: [0.0005]
# epoch: 51.0000, train_loss_bpr: 0.0111, test_loss_bpr: 1.8472, precision@k: 0.0234, recall@k: 0.0343, map@k: 0.0206, mrr@k: 0.0367, ndcg@k: 0.0312, hit_rate@k: 0.0793
# learning rate: [0.0005]
# epoch: 52.0000, train_loss_bpr: 0.0117, test_loss_bpr: 1.8193, precision@k: 0.0234, recall@k: 0.0352, map@k: 0.0208, mrr@k: 0.0369, ndcg@k: 0.0315, hit_rate@k: 0.0793
# learning rate: [0.0005]
# epoch: 53.0000, train_loss_bpr: 0.0137, test_loss_bpr: 1.7955, precision@k: 0.0234, recall@k: 0.0353, map@k: 0.0201, mrr@k: 0.0357, ndcg@k: 0.0309, hit_rate@k: 0.0801
# learning rate: [0.0005]
# epoch: 54.0000, train_loss_bpr: 0.0094, test_loss_bpr: 1.7720, precision@k: 0.0230, recall@k: 0.0348, map@k: 0.0196, mrr@k: 0.0354, ndcg@k: 0.0305, hit_rate@k: 0.0801
# learning rate: [0.0005]
# epoch: 55.0000, train_loss_bpr: 0.0103, test_loss_bpr: 1.7535, precision@k: 0.0234, recall@k: 0.0351, map@k: 0.0199, mrr@k: 0.0361, ndcg@k: 0.0309, hit_rate@k: 0.0810
# learning rate: [0.0005]
# epoch: 56.0000, train_loss_bpr: 0.0138, test_loss_bpr: 1.7302, precision@k: 0.0224, recall@k: 0.0345, map@k: 0.0193, mrr@k: 0.0355, ndcg@k: 0.0301, hit_rate@k: 0.0793
# learning rate: [0.0005]
# epoch: 57.0000, train_loss_bpr: 0.0126, test_loss_bpr: 1.7118, precision@k: 0.0224, recall@k: 0.0357, map@k: 0.0189, mrr@k: 0.0354, ndcg@k: 0.0301, hit_rate@k: 0.0818
# learning rate: [0.0005]
# epoch: 58.0000, train_loss_bpr: 0.0099, test_loss_bpr: 1.6927, precision@k: 0.0225, recall@k: 0.0365, map@k: 0.0190, mrr@k: 0.0354, ndcg@k: 0.0303, hit_rate@k: 0.0818
# learning rate: [0.0005]
# epoch: 59.0000, train_loss_bpr: 0.0124, test_loss_bpr: 1.6739, precision@k: 0.0222, recall@k: 0.0363, map@k: 0.0187, mrr@k: 0.0351, ndcg@k: 0.0299, hit_rate@k: 0.0818
# learning rate: [0.0005]
# epoch: 60.0000, train_loss_bpr: 0.0147, test_loss_bpr: 1.6547, precision@k: 0.0224, recall@k: 0.0378, map@k: 0.0189, mrr@k: 0.0358, ndcg@k: 0.0305, hit_rate@k: 0.0835
# learning rate: [0.0005]
# epoch: 61.0000, train_loss_bpr: 0.0131, test_loss_bpr: 1.6341, precision@k: 0.0222, recall@k: 0.0378, map@k: 0.0189, mrr@k: 0.0359, ndcg@k: 0.0304, hit_rate@k: 0.0835
# learning rate: [0.0005]
# epoch: 62.0000, train_loss_bpr: 0.0107, test_loss_bpr: 1.6120, precision@k: 0.0224, recall@k: 0.0383, map@k: 0.0190, mrr@k: 0.0363, ndcg@k: 0.0306, hit_rate@k: 0.0851
# learning rate: [0.0005]
# epoch: 63.0000, train_loss_bpr: 0.0085, test_loss_bpr: 1.5949, precision@k: 0.0259, recall@k: 0.0389, map@k: 0.0199, mrr@k: 0.0411, ndcg@k: 0.0333, hit_rate@k: 0.1035
# learning rate: [0.0005]
# epoch: 64.0000, train_loss_bpr: 0.0078, test_loss_bpr: 1.5788, precision@k: 0.0254, recall@k: 0.0377, map@k: 0.0197, mrr@k: 0.0408, ndcg@k: 0.0328, hit_rate@k: 0.1010
# learning rate: [0.0005]
# epoch: 65.0000, train_loss_bpr: 0.0119, test_loss_bpr: 1.5673, precision@k: 0.0265, recall@k: 0.0383, map@k: 0.0201, mrr@k: 0.0420, ndcg@k: 0.0337, hit_rate@k: 0.1060
# learning rate: [0.0005]
# epoch: 66.0000, train_loss_bpr: 0.0116, test_loss_bpr: 1.5576, precision@k: 0.0264, recall@k: 0.0382, map@k: 0.0205, mrr@k: 0.0437, ndcg@k: 0.0342, hit_rate@k: 0.1060
# learning rate: [0.0005]
# epoch: 67.0000, train_loss_bpr: 0.0146, test_loss_bpr: 1.5471, precision@k: 0.0264, recall@k: 0.0394, map@k: 0.0208, mrr@k: 0.0439, ndcg@k: 0.0346, hit_rate@k: 0.1060
# learning rate: [0.0005]
# epoch: 68.0000, train_loss_bpr: 0.0144, test_loss_bpr: 1.5376, precision@k: 0.0262, recall@k: 0.0396, map@k: 0.0208, mrr@k: 0.0442, ndcg@k: 0.0347, hit_rate@k: 0.1068
# learning rate: [0.0005]
# epoch: 69.0000, train_loss_bpr: 0.0065, test_loss_bpr: 1.5311, precision@k: 0.0262, recall@k: 0.0391, map@k: 0.0213, mrr@k: 0.0450, ndcg@k: 0.0350, hit_rate@k: 0.1077
# learning rate: [0.0005]
# epoch: 70.0000, train_loss_bpr: 0.0136, test_loss_bpr: 1.5274, precision@k: 0.0257, recall@k: 0.0380, map@k: 0.0210, mrr@k: 0.0444, ndcg@k: 0.0344, hit_rate@k: 0.1060
# learning rate: [0.0005]
# epoch: 71.0000, train_loss_bpr: 0.0085, test_loss_bpr: 1.5244, precision@k: 0.0260, recall@k: 0.0388, map@k: 0.0207, mrr@k: 0.0427, ndcg@k: 0.0342, hit_rate@k: 0.1068
# learning rate: [0.0005]
# epoch: 72.0000, train_loss_bpr: 0.0120, test_loss_bpr: 1.5194, precision@k: 0.0260, recall@k: 0.0395, map@k: 0.0208, mrr@k: 0.0416, ndcg@k: 0.0342, hit_rate@k: 0.1052
# learning rate: [0.0005]
# epoch: 73.0000, train_loss_bpr: 0.0095, test_loss_bpr: 1.5213, precision@k: 0.0262, recall@k: 0.0403, map@k: 0.0212, mrr@k: 0.0425, ndcg@k: 0.0348, hit_rate@k: 0.1060
# learning rate: [0.0005]
# epoch: 74.0000, train_loss_bpr: 0.0105, test_loss_bpr: 1.5207, precision@k: 0.0225, recall@k: 0.0389, map@k: 0.0200, mrr@k: 0.0372, ndcg@k: 0.0317, hit_rate@k: 0.0868
# learning rate: [0.0005]
# epoch: 75.0000, train_loss_bpr: 0.0105, test_loss_bpr: 1.5203, precision@k: 0.0225, recall@k: 0.0385, map@k: 0.0197, mrr@k: 0.0368, ndcg@k: 0.0314, hit_rate@k: 0.0868
# learning rate: [0.00025]
# epoch: 76.0000, train_loss_bpr: 0.0113, test_loss_bpr: 1.5217, precision@k: 0.0227, recall@k: 0.0379, map@k: 0.0194, mrr@k: 0.0366, ndcg@k: 0.0310, hit_rate@k: 0.0868
# learning rate: [0.00025]
# epoch: 77.0000, train_loss_bpr: 0.0136, test_loss_bpr: 1.5241, precision@k: 0.0229, recall@k: 0.0379, map@k: 0.0195, mrr@k: 0.0367, ndcg@k: 0.0311, hit_rate@k: 0.0868
# learning rate: [0.00025]
# epoch: 78.0000, train_loss_bpr: 0.0092, test_loss_bpr: 1.5273, precision@k: 0.0230, recall@k: 0.0377, map@k: 0.0196, mrr@k: 0.0366, ndcg@k: 0.0312, hit_rate@k: 0.0860
# learning rate: [0.00025]
# epoch: 79.0000, train_loss_bpr: 0.0075, test_loss_bpr: 1.5304, precision@k: 0.0229, recall@k: 0.0374, map@k: 0.0193, mrr@k: 0.0368, ndcg@k: 0.0310, hit_rate@k: 0.0860
# learning rate: [0.000125]
# epoch: 80.0000, train_loss_bpr: 0.0109, test_loss_bpr: 1.5328, precision@k: 0.0230, recall@k: 0.0383, map@k: 0.0197, mrr@k: 0.0377, ndcg@k: 0.0316, hit_rate@k: 0.0868
# learning rate: [0.000125]
# epoch: 81.0000, train_loss_bpr: 0.0086, test_loss_bpr: 1.5336, precision@k: 0.0232, recall@k: 0.0384, map@k: 0.0199, mrr@k: 0.0377, ndcg@k: 0.0318, hit_rate@k: 0.0868
# learning rate: [0.000125]
# epoch: 82.0000, train_loss_bpr: 0.0096, test_loss_bpr: 1.5356, precision@k: 0.0234, recall@k: 0.0386, map@k: 0.0199, mrr@k: 0.0377, ndcg@k: 0.0319, hit_rate@k: 0.0868
# learning rate: [0.000125]
# epoch: 83.0000, train_loss_bpr: 0.0134, test_loss_bpr: 1.5374, precision@k: 0.0232, recall@k: 0.0385, map@k: 0.0199, mrr@k: 0.0377, ndcg@k: 0.0318, hit_rate@k: 0.0868
# learning rate: [6.25e-05]
# epoch: 84.0000, train_loss_bpr: 0.0088, test_loss_bpr: 1.5400, precision@k: 0.0230, recall@k: 0.0385, map@k: 0.0198, mrr@k: 0.0377, ndcg@k: 0.0316, hit_rate@k: 0.0868
# learning rate: [6.25e-05]
# epoch: 85.0000, train_loss_bpr: 0.0114, test_loss_bpr: 1.5417, precision@k: 0.0230, recall@k: 0.0381, map@k: 0.0197, mrr@k: 0.0375, ndcg@k: 0.0316, hit_rate@k: 0.0860
# learning rate: [6.25e-05]
# epoch: 86.0000, train_loss_bpr: 0.0120, test_loss_bpr: 1.5433, precision@k: 0.0229, recall@k: 0.0381, map@k: 0.0197, mrr@k: 0.0375, ndcg@k: 0.0314, hit_rate@k: 0.0860
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[115], line 18
#      16 for epoch in range(1,  100 + 1):
#      17     train_loss = train()
# ---> 18     test_loss = test()
#      19     scheduler.step(test_loss)
#      20     eval_result = evaluate(k=num_recommendations)
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[19], line 83, in test()
#      75 edge_label_index = torch.cat([
#      76     pos_edge_index,
#      77     neg_edge_index,
#      78 ], dim=1)
#      80 # We encode the training edge index to get the embeddings based on the training graph
#      81 # structure and then use those embeddings to predict unseen edges
#      82 # TODO: Check if this makes sense
# ---> 83 pos_edge_rank, neg_edge_rank = model(x_dict=data.x_dict,
#      84                                      edge_index_dict=data.train_edge_index_dict,
#      85                                      edge_label_index=edge_label_index).chunk(2)
#      87 # Calculate BPR loss
#      88 loss = model.recommendation_loss(x_dict=data.x_dict,
#      89                                  edge_index_dict=data.train_edge_index_dict,
#      90                                  pos_edge_rank=pos_edge_rank,
#      91                                  neg_edge_rank=neg_edge_rank,
#      92                                  node_id=edge_label_index.unique())
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[96], line 120, in CollaborationRecommender.forward(self, x_dict, edge_index_dict, edge_label_index)
#     114 def forward(self,
#     115             x_dict,
#     116             edge_index_dict,
#     117             edge_label_index: OptTensor = None):
#     118
#     119     # Encode authors
# --> 120     z_dict = self.encoder(x_dict, edge_index_dict)
#     121     z = z_dict['author']
#     122     # Decode edges
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/fx/graph_module.py:738, in GraphModule.recompile.<locals>.call_wrapped(self, *args, **kwargs)
#     737 def call_wrapped(self, *args, **kwargs):
# --> 738     return self._wrapped_call(self, *args, **kwargs)
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/fx/graph_module.py:303, in _WrappedCall.__call__(self, obj, *args, **kwargs)
#     301         return self.cls_call(obj, *args, **kwargs)
#     302     else:
# --> 303         return super(self.cls, obj).__call__(*args, **kwargs)  # type: ignore[misc]
#     304 except Exception as e:
#     305     assert e.__traceback__
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File <eval_with_key>.53:18, in forward(self, x, edge_index)
#      16 bn_layers_0__article = getattr(self.bn_layers, "0").article(conv_layers_0__article);  conv_layers_0__article = None
#      17 bn_layers_0__author = getattr(self.bn_layers, "0").author(conv_layers_0__author);  conv_layers_0__author = None
# ---> 18 conv_layers_1__article = getattr(self.conv_layers, "1").author__publishes__article((bn_layers_0__author, bn_layers_0__article), edge_index__author__publishes__article)
#      19 conv_layers_1__author1 = getattr(self.conv_layers, "1").author__co_authors__author(bn_layers_0__author, edge_index__author__co_authors__author)
#      20 conv_layers_1__author2 = getattr(self.conv_layers, "1").article__rev_publishes__author((bn_layers_0__article, bn_layers_0__author), edge_index__article__rev_publishes__author);  bn_layers_0__article = bn_layers_0__author = None
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch_geometric/nn/conv/transformer_conv.py:229, in TransformerConv.forward(self, x, edge_index, edge_attr, return_attention_weights)
#     225 value = self.lin_value(x[0]).view(-1, H, C)
#     227 # propagate_type: (query: Tensor, key:Tensor, value: Tensor,
#     228 #                  edge_attr: OptTensor)
# --> 229 out = self.propagate(edge_index, query=query, key=key, value=value,
#     230                      edge_attr=edge_attr)
#     232 alpha = self._alpha
#     233 self._alpha = None
#
# File /tmp/torch_geometric.nn.conv.transformer_conv_TransformerConv_propagate_dqta2t_1.py:201, in propagate(self, edge_index, query, key, value, edge_attr, size)
#     197     raise NotImplementedError("'message_and_aggregate' not implemented")
#     199 else:
# --> 201     kwargs = self.collect(
#     202         edge_index,
#     203         query,
#     204         key,
#     205         value,
#     206         edge_attr,
#     207         mutable_size,
#     208     )
#     210     # Begin Message Forward Pre Hook #######################################
#     211     if not torch.jit.is_scripting() and not is_compiling():
#
# File /tmp/torch_geometric.nn.conv.transformer_conv_TransformerConv_propagate_dqta2t_1.py:102, in collect(self, edge_index, query, key, value, edge_attr, size)
#     100 elif isinstance(query, Tensor):
#     101     self._set_size(size, i, query)
# --> 102     query_i = self._index_select(query, edge_index_i)
#     103 else:
#     104     query_i = None
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch_geometric/nn/conv/message_passing.py:267, in MessagePassing._index_select(self, src, index)
#     265     return src.index_select(self.node_dim, index)
#     266 else:
# --> 267     return self._index_select_safe(src, index)
#
# File ~/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch_geometric/nn/conv/message_passing.py:271, in MessagePassing._index_select_safe(self, src, index)
#     269 def _index_select_safe(self, src: Tensor, index: Tensor) -> Tensor:
#     270     try:
# --> 271         return src.index_select(self.node_dim, index)
#     272     except (IndexError, RuntimeError) as e:
#     273         if index.numel() > 0 and index.min() < 0:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Model evaluation

# %%
results = pd.DataFrame(results)

# %%
# Generate loss curve
plt.plot(results['epoch'], results['train_loss_bpr'], label='train')
plt.plot(results['epoch'], results['test_loss_bpr'], label='test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Loss Curve')
plt.show()

# %%
# Generate evaluation metrics plot
plt.plot(results['epoch'], results['precision@k'], label='precision@k')
plt.plot(results['epoch'], results['recall@k'], label='recall@k')
plt.plot(results['epoch'], results['map@k'], label='map@k')
plt.plot(results['epoch'], results['mrr@k'], label='mrr@k')
plt.plot(results['epoch'], results['ndcg@k'], label='ndcg@k')
plt.plot(results['epoch'], results['hit_rate@k'], label='hit_rate@k')
plt.xlabel('Epoch')
plt.ylabel('Performance')
plt.title('Evaluation metrics')
plt.legend()
plt.show()

# %%
results['epoch'] = results['epoch'].astype(int)
results['train_loss_bpr'] = results['train_loss_bpr'].astype(float)
results['test_loss_bpr'] = results['test_loss_bpr'].astype(float)
results['precision@k'] = results['precision@k'].astype(float)
results['recall@k'] = results['recall@k'].astype(float)
results['map@k'] = results['map@k'].astype(float)
results['mrr@k'] = results['mrr@k'].astype(float)
results['ndcg@k'] = results['ndcg@k'].astype(float)
results['hit_rate@k'] = results['hit_rate@k'].astype(float)
results
# Out:
#     epoch  train_loss_bpr  test_loss_bpr  precision@k  recall@k     map@k  \
# 0       1        1.550628       4.048902     0.009265  0.011003  0.006664
# 1       2        1.313427       3.148557     0.012604  0.019838  0.009326
# 2       3        1.142816       2.541307     0.014357  0.025604  0.011682
# 3       4        1.030980       2.171380     0.016778  0.037143  0.013797
# 4       5        0.929129       1.928342     0.017446  0.038909  0.015307
# 5       6        0.798026       1.777517     0.017529  0.038664  0.015014
# 6       7        0.839438       1.690301     0.018197  0.042767  0.016186
# 7       8        0.776909       1.633077     0.018030  0.040397  0.017662
# 8       9        0.715958       1.595211     0.018280  0.042560  0.016397
# 9      10        0.732971       1.568492     0.018280  0.042498  0.016384
# 10     11        0.659752       1.542608     0.018364  0.043638  0.017408
# 11     12        0.562317       1.520941     0.018030  0.043400  0.016866
# 12     13        0.611369       1.500651     0.018280  0.044447  0.016323
# 13     14        0.531769       1.482153     0.018865  0.045093  0.018193
# 14     15        0.587977       1.458724     0.019282  0.045835  0.018481
# 15     16        0.538033       1.436518     0.019366  0.046559  0.019690
# 16     17        0.496695       1.417373     0.019783  0.047955  0.018705
# 17     18        0.471692       1.396803     0.019950  0.049465  0.018749
# 18     19        0.515602       1.372079     0.020200  0.049827  0.018832
# 19     20        0.474728       1.347741     0.020200  0.048704  0.018764
# 20     21        0.433318       1.326633     0.020367  0.050445  0.017555
# 21     22        0.457185       1.310510     0.018948  0.051240  0.017521
# 22     23        0.421757       1.293034     0.019199  0.051459  0.017620
# 23     24        0.456838       1.276547     0.020785  0.050833  0.019359
# 24     25        0.413306       1.266982     0.020785  0.051618  0.019053
# 25     26        0.368358       1.254967     0.020868  0.051702  0.019506
# 26     27        0.440827       1.245105     0.020952  0.051946  0.019549
# 27     28        0.395548       1.235627     0.021202  0.052506  0.020494
# 28     29        0.392213       1.234468     0.020868  0.052512  0.020282
# 29     30        0.344505       1.230014     0.021369  0.053404  0.021139
# 30     31        0.399800       1.221508     0.021536  0.053881  0.019661
# 31     32        0.401322       1.214402     0.021285  0.053690  0.020129
# 32     33        0.355629       1.217341     0.021703  0.054324  0.019491
# 33     34        0.362824       1.219541     0.021536  0.053956  0.020511
# 34     35        0.379788       1.227556     0.021953  0.055360  0.019937
# 35     36        0.400872       1.226374     0.021953  0.055417  0.021167
# 36     37        0.332324       1.232319     0.021870  0.054618  0.019519
# 37     38        0.385692       1.236323     0.022120  0.055547  0.021053
# 38     39        0.343194       1.232932     0.021786  0.055616  0.021037
# 39     40        0.356299       1.230803     0.022037  0.053416  0.020172
# 40     41        0.375793       1.231288     0.022287  0.054335  0.021699
# 41     42        0.318100       1.229681     0.021536  0.052699  0.019838
# 42     43        0.338238       1.223341     0.021953  0.053635  0.020794
# 43     44        0.346193       1.219127     0.021953  0.052884  0.021755
# 44     45        0.328490       1.215790     0.022037  0.053718  0.021791
# 45     46        0.350264       1.218014     0.022037  0.053718  0.020982
# 46     47        0.347972       1.218822     0.021870  0.052884  0.020496
# 47     48        0.320749       1.223422     0.022120  0.054136  0.022510
#
#        mrr@k    ndcg@k  hit_rate@k
# 0   0.025823  0.013054    0.045075
# 1   0.024306  0.017992    0.070117
# 2   0.030582  0.021973    0.081803
# 3   0.030891  0.026622    0.096828
# 4   0.035236  0.028581    0.099332
# 5   0.034959  0.028182    0.096828
# 6   0.030228  0.029503    0.102671
# 7   0.037852  0.030860    0.101002
# 8   0.032673  0.030049    0.102671
# 9   0.035256  0.030404    0.106010
# 10  0.039566  0.031816    0.107679
# 11  0.034775  0.030751    0.106845
# 12  0.033059  0.030458    0.106845
# 13  0.049022  0.033692    0.112688
# 14  0.041067  0.033586    0.113523
# 15  0.049918  0.035350    0.113523
# 16  0.039201  0.034097    0.116027
# 17  0.040303  0.034626    0.117696
# 18  0.041105  0.034957    0.116861
# 19  0.041310  0.034689    0.115192
# 20  0.035522  0.033504    0.116861
# 21  0.034402  0.032964    0.118531
# 22  0.040355  0.033831    0.119366
# 23  0.040816  0.035687    0.117696
# 24  0.039869  0.035586    0.117696
# 25  0.041950  0.036084    0.118531
# 26  0.039338  0.035867    0.118531
# 27  0.042938  0.037255    0.119366
# 28  0.042229  0.036640    0.117696
# 29  0.042105  0.037740    0.121870
# 30  0.041012  0.036583    0.121870
# 31  0.038845  0.036705    0.121035
# 32  0.039041  0.036514    0.123539
# 33  0.040003  0.037321    0.123539
# 34  0.038176  0.036901    0.125209
# 35  0.042102  0.038399    0.126043
# 36  0.037254  0.036421    0.124374
# 37  0.043725  0.038674    0.125209
# 38  0.041714  0.038085    0.125209
# 39  0.038763  0.036830    0.122705
# 40  0.047966  0.039242    0.124374
# 41  0.037694  0.036200    0.122705
# 42  0.042495  0.037765    0.124374
# 43  0.053845  0.039385    0.123539
# 44  0.053007  0.039474    0.124374
# 45  0.043143  0.037901    0.124374
# 46  0.039435  0.036938    0.122705
# 47  0.044655  0.039317    0.124374

# %%
results.to_csv('../results/results_EuCoHT.csv')
