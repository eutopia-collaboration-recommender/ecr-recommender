# %% [markdown]
# # Model F
#
# This is a script showing results of **model F** in the ablation studies. The model is built using the following configuration:
#
# - **Backbone:** Transformer
# - **Graph type:** Homogeneous
# - **Loss function:** Binary-Cross Entropy with Logits Loss
# - **Embeddings used:** average
# - **Keyword popularity used:** No
#
# *This model introduces a baseline loss function Binary-Cross Entropy with Logits loss to compare against Bayesian Personalized Ranking on graph transformer backbone.*

# %% [markdown]
# ## **Setting up environment**
#
# ---

# %% [markdown]
# ### Loading libraries

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))

import torch
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from typing import Optional

from torch import Tensor
from torch.nn import ModuleList
import torch.nn.functional as F
from torch.optim import Optimizer
from torch_geometric.typing import Adj, OptTensor
from torch_geometric.nn.conv import TransformerConv
from torch.optim.lr_scheduler import LRScheduler
from torch_geometric.data import Data

from util.torch_geometric import get_results
from util.homogeneous.dataset import (DatasetEuCoHM, load_dataset)
from util.homogeneous.model import ModelEuCoHM
from util.homogeneous.train import (
    train,
    test,
    evaluate
)

# %% [markdown]
# ### Global variables

# %%
# Model name
model_name = 'F'
# Dataset save filepath
dataset_save_filepath_prefix = '../data/dataset_homogeneous_base'
# Device name
device = 'cpu'

# Model configuration
model_config = dict(
    hidden_channels=64,
    learning_rate=1e-3,
    num_layers=4,
    num_heads=4,
    num_epochs=50,
    num_recommendations=10,
    num_bootstrap=10
)
# Set seaborn theme
sns.set_theme(style="whitegrid", palette="pastel")

# %% [markdown]
# ## Model training
#
#
# ---

# %% [markdown]
# ### Model definition

# %%
class ModelEuCoF(ModelEuCoHM):
    def __init__(self,
                 input_channels: int,
                 hidden_channels: int,
                 num_layers: int,
                 num_recommendations: int,
                 num_heads: int,
                 author_node_id_map: dict,
                 author_id_map: dict,
                 device: str = 'cpu'):
        super().__init__(
            input_channels=input_channels,
            hidden_channels=hidden_channels,
            num_layers=num_layers,
            num_recommendations=num_recommendations,
            author_node_id_map=author_node_id_map,
            author_id_map=author_id_map,
            device=device
        )
        # Set number of attention heads
        self.num_heads = num_heads

        # Initialize the convolutional layers
        self.conv_layers = ModuleList([
            TransformerConv(in_channels=input_channels if ix == 0 else hidden_channels * self.num_heads, 
                            out_channels=hidden_channels,
                            heads=self.num_heads)
            for ix in range(self.num_layers)
        ])

        # Initialize batch norm layers
        self.bn_layers = ModuleList([
            torch.nn.BatchNorm1d(hidden_channels * self.num_heads)
            for ix in range(self.num_layers)
        ])
    
    def recommendation_loss(self,
                            x: Tensor,
                            edge_index: Adj,
                            pos_edge_rank: Tensor,
                            neg_edge_rank: Tensor,
                            edge_weight: Optional[Tensor] = None,
                            node_id: Optional[Tensor] = None) -> Tensor:

        # Construct labels
        pos_labels = pos_edge_rank.new_ones(pos_edge_rank.size(0))
        neg_labels = neg_edge_rank.new_zeros(neg_edge_rank.size(0))

        # Concatenate predictions and labels
        all_preds = torch.cat([pos_edge_rank, neg_edge_rank], dim=0)
        all_labels = torch.cat([pos_labels, neg_labels], dim=0)

        # Compute BCE loss
        bce_loss = F.binary_cross_entropy_with_logits(all_preds, all_labels)

        return bce_loss

# %% [markdown]
# ### Training the model

# %%
def load_model(data: Data, model_config: dict, author_node_id_map: dict, author_id_map: dict):
    # Initialize the model
    model = ModelEuCoF(
        input_channels=data.num_features,
        hidden_channels=model_config['hidden_channels'],
        num_recommendations=model_config['num_recommendations'],
        num_layers=model_config['num_layers'],
        num_heads=model_config['num_heads'],
        author_node_id_map=author_node_id_map,
        author_id_map=author_id_map
    ).to(device)
    
    # Initialize the optimizer
    optimizer: Optimizer = torch.optim.Adam(
        params=model.parameters(),
        lr=model_config['learning_rate']
    )
    
    # Initialize the scheduler
    scheduler: LRScheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        mode='min',
        factor=0.5,
        patience=10
    )
    
    return model, data, optimizer, scheduler

# %%
results: list = list()
for bootstrap_id in range(model_config['num_bootstrap']):
    print(f'Processing bootstrap dataset ix={bootstrap_id}...')
    dataset_filepath = f'{dataset_save_filepath_prefix}_b{bootstrap_id}.pkl'
    data, author_id_map, author_node_id_map = load_dataset(dataset_filepath=dataset_filepath, device=device)
    model, data, optimizer, scheduler = load_model(data, model_config, author_node_id_map, author_id_map)
    for epoch in range(1, model_config['num_epochs'] + 1):
        # ------ Train
        train_loss: float = train(
            model=model,
            data=data,
            optimizer=optimizer
        )
        # ------ Test
        test_loss: float = test(
            model=model,
            data=data
        )
        scheduler.step(test_loss)
        # ------ Evaluate
        evaluation_results: dict = evaluate(
            k=model_config['num_recommendations'],
            model=model,
            data=data
        )
    
        # Save results
        epoch_result = get_results(
            epoch=epoch,
            train_loss=train_loss,
            test_loss=test_loss,
            evaluation_results=evaluation_results,
            bootstrap_id=bootstrap_id,
            log_every_n_epochs=10
        )
        results.append(epoch_result)
# Out:
# Processing bootstrap dataset ix=0...
# /home/eucollab/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Epoch 10, train loss: 0.5207, test loss: 0.5619, precision@k: 0.0446, recall@k: 0.1282, MAP@k: 0.0636, MRR@k: 0.1127, NDCG@k: 0.0956, HitRate@k: 0.2373
# Epoch 20, train loss: 0.3949, test loss: 0.5643, precision@k: 0.0443, recall@k: 0.1280, MAP@k: 0.0622, MRR@k: 0.1108, NDCG@k: 0.0945, HitRate@k: 0.2377
# Epoch 30, train loss: 0.3755, test loss: 0.5350, precision@k: 0.0455, recall@k: 0.1327, MAP@k: 0.0638, MRR@k: 0.1133, NDCG@k: 0.0971, HitRate@k: 0.2451
# Epoch 40, train loss: 0.3690, test loss: 0.5166, precision@k: 0.0460, recall@k: 0.1355, MAP@k: 0.0645, MRR@k: 0.1137, NDCG@k: 0.0984, HitRate@k: 0.2492
# Epoch 50, train loss: 0.3622, test loss: 0.5090, precision@k: 0.0463, recall@k: 0.1377, MAP@k: 0.0654, MRR@k: 0.1154, NDCG@k: 0.0997, HitRate@k: 0.2524
# Processing bootstrap dataset ix=1...
# Epoch 10, train loss: 0.4852, test loss: 0.5450, precision@k: 0.0461, recall@k: 0.1327, MAP@k: 0.0658, MRR@k: 0.1189, NDCG@k: 0.0993, HitRate@k: 0.2462
# Epoch 20, train loss: 0.3857, test loss: 0.5894, precision@k: 0.0453, recall@k: 0.1303, MAP@k: 0.0642, MRR@k: 0.1157, NDCG@k: 0.0972, HitRate@k: 0.2455
# Epoch 30, train loss: 0.3725, test loss: 0.5338, precision@k: 0.0455, recall@k: 0.1322, MAP@k: 0.0639, MRR@k: 0.1152, NDCG@k: 0.0974, HitRate@k: 0.2472
# Epoch 40, train loss: 0.3684, test loss: 0.5050, precision@k: 0.0458, recall@k: 0.1340, MAP@k: 0.0644, MRR@k: 0.1156, NDCG@k: 0.0983, HitRate@k: 0.2500
# Epoch 50, train loss: 0.3654, test loss: 0.4970, precision@k: 0.0462, recall@k: 0.1355, MAP@k: 0.0646, MRR@k: 0.1161, NDCG@k: 0.0989, HitRate@k: 0.2524
# Processing bootstrap dataset ix=2...
# Epoch 10, train loss: 0.5004, test loss: 0.5483, precision@k: 0.0438, recall@k: 0.1284, MAP@k: 0.0632, MRR@k: 0.1120, NDCG@k: 0.0951, HitRate@k: 0.2361
# Epoch 20, train loss: 0.3908, test loss: 0.5857, precision@k: 0.0427, recall@k: 0.1258, MAP@k: 0.0613, MRR@k: 0.1089, NDCG@k: 0.0927, HitRate@k: 0.2324
# Epoch 30, train loss: 0.3749, test loss: 0.5292, precision@k: 0.0437, recall@k: 0.1308, MAP@k: 0.0624, MRR@k: 0.1111, NDCG@k: 0.0950, HitRate@k: 0.2411
# Epoch 40, train loss: 0.3708, test loss: 0.5041, precision@k: 0.0439, recall@k: 0.1321, MAP@k: 0.0627, MRR@k: 0.1117, NDCG@k: 0.0956, HitRate@k: 0.2433
# Epoch 50, train loss: 0.3684, test loss: 0.4963, precision@k: 0.0444, recall@k: 0.1337, MAP@k: 0.0634, MRR@k: 0.1130, NDCG@k: 0.0967, HitRate@k: 0.2464
# Processing bootstrap dataset ix=3...
# Epoch 10, train loss: 0.4835, test loss: 0.5540, precision@k: 0.0455, recall@k: 0.1318, MAP@k: 0.0658, MRR@k: 0.1152, NDCG@k: 0.0983, HitRate@k: 0.2418
# Epoch 20, train loss: 0.3851, test loss: 0.5922, precision@k: 0.0448, recall@k: 0.1316, MAP@k: 0.0637, MRR@k: 0.1120, NDCG@k: 0.0964, HitRate@k: 0.2413
# Epoch 30, train loss: 0.3718, test loss: 0.5250, precision@k: 0.0457, recall@k: 0.1354, MAP@k: 0.0646, MRR@k: 0.1132, NDCG@k: 0.0982, HitRate@k: 0.2483
# Epoch 40, train loss: 0.3684, test loss: 0.5007, precision@k: 0.0463, recall@k: 0.1381, MAP@k: 0.0658, MRR@k: 0.1145, NDCG@k: 0.0999, HitRate@k: 0.2525
# Epoch 50, train loss: 0.3656, test loss: 0.4952, precision@k: 0.0466, recall@k: 0.1395, MAP@k: 0.0663, MRR@k: 0.1153, NDCG@k: 0.1007, HitRate@k: 0.2540
# Processing bootstrap dataset ix=4...
# Epoch 10, train loss: 0.5045, test loss: 0.5644, precision@k: 0.0448, recall@k: 0.1306, MAP@k: 0.0643, MRR@k: 0.1142, NDCG@k: 0.0970, HitRate@k: 0.2416
# Epoch 20, train loss: 0.3908, test loss: 0.5850, precision@k: 0.0443, recall@k: 0.1299, MAP@k: 0.0622, MRR@k: 0.1104, NDCG@k: 0.0949, HitRate@k: 0.2424
# Epoch 30, train loss: 0.3743, test loss: 0.5354, precision@k: 0.0447, recall@k: 0.1327, MAP@k: 0.0628, MRR@k: 0.1118, NDCG@k: 0.0961, HitRate@k: 0.2452
# Epoch 40, train loss: 0.3701, test loss: 0.5081, precision@k: 0.0450, recall@k: 0.1334, MAP@k: 0.0631, MRR@k: 0.1122, NDCG@k: 0.0966, HitRate@k: 0.2475
# Epoch 50, train loss: 0.3674, test loss: 0.4990, precision@k: 0.0454, recall@k: 0.1346, MAP@k: 0.0638, MRR@k: 0.1135, NDCG@k: 0.0976, HitRate@k: 0.2495
# Processing bootstrap dataset ix=5...
# Epoch 10, train loss: 0.4983, test loss: 0.5739, precision@k: 0.0447, recall@k: 0.1308, MAP@k: 0.0638, MRR@k: 0.1136, NDCG@k: 0.0964, HitRate@k: 0.2414
# Epoch 20, train loss: 0.3878, test loss: 0.5865, precision@k: 0.0437, recall@k: 0.1285, MAP@k: 0.0619, MRR@k: 0.1092, NDCG@k: 0.0938, HitRate@k: 0.2378
# Epoch 30, train loss: 0.3744, test loss: 0.5296, precision@k: 0.0442, recall@k: 0.1316, MAP@k: 0.0625, MRR@k: 0.1098, NDCG@k: 0.0951, HitRate@k: 0.2440
# Epoch 40, train loss: 0.3688, test loss: 0.5076, precision@k: 0.0448, recall@k: 0.1334, MAP@k: 0.0631, MRR@k: 0.1116, NDCG@k: 0.0963, HitRate@k: 0.2469
# Epoch 50, train loss: 0.3657, test loss: 0.5001, precision@k: 0.0453, recall@k: 0.1358, MAP@k: 0.0635, MRR@k: 0.1122, NDCG@k: 0.0973, HitRate@k: 0.2504
# Processing bootstrap dataset ix=6...
# Epoch 10, train loss: 0.4968, test loss: 0.5535, precision@k: 0.0443, recall@k: 0.1300, MAP@k: 0.0631, MRR@k: 0.1104, NDCG@k: 0.0951, HitRate@k: 0.2372
# Epoch 20, train loss: 0.3883, test loss: 0.5763, precision@k: 0.0438, recall@k: 0.1279, MAP@k: 0.0611, MRR@k: 0.1100, NDCG@k: 0.0934, HitRate@k: 0.2381
# Epoch 30, train loss: 0.3742, test loss: 0.5340, precision@k: 0.0438, recall@k: 0.1278, MAP@k: 0.0612, MRR@k: 0.1093, NDCG@k: 0.0933, HitRate@k: 0.2357
# Epoch 40, train loss: 0.3694, test loss: 0.5167, precision@k: 0.0446, recall@k: 0.1303, MAP@k: 0.0616, MRR@k: 0.1094, NDCG@k: 0.0943, HitRate@k: 0.2399
# Epoch 50, train loss: 0.3667, test loss: 0.5098, precision@k: 0.0450, recall@k: 0.1319, MAP@k: 0.0620, MRR@k: 0.1099, NDCG@k: 0.0951, HitRate@k: 0.2426
# Processing bootstrap dataset ix=7...
# Epoch 10, train loss: 0.4892, test loss: 0.5610, precision@k: 0.0436, recall@k: 0.1252, MAP@k: 0.0608, MRR@k: 0.1094, NDCG@k: 0.0924, HitRate@k: 0.2336
# Epoch 20, train loss: 0.3883, test loss: 0.5934, precision@k: 0.0431, recall@k: 0.1240, MAP@k: 0.0604, MRR@k: 0.1087, NDCG@k: 0.0918, HitRate@k: 0.2335
# Epoch 30, train loss: 0.3748, test loss: 0.5330, precision@k: 0.0441, recall@k: 0.1292, MAP@k: 0.0612, MRR@k: 0.1098, NDCG@k: 0.0939, HitRate@k: 0.2420
# Epoch 40, train loss: 0.3703, test loss: 0.5075, precision@k: 0.0446, recall@k: 0.1310, MAP@k: 0.0621, MRR@k: 0.1110, NDCG@k: 0.0951, HitRate@k: 0.2450
# Epoch 50, train loss: 0.3674, test loss: 0.5002, precision@k: 0.0451, recall@k: 0.1333, MAP@k: 0.0631, MRR@k: 0.1126, NDCG@k: 0.0966, HitRate@k: 0.2482
# Processing bootstrap dataset ix=8...
# Epoch 10, train loss: 0.5047, test loss: 0.5485, precision@k: 0.0448, recall@k: 0.1318, MAP@k: 0.0660, MRR@k: 0.1165, NDCG@k: 0.0985, HitRate@k: 0.2408
# Epoch 20, train loss: 0.3941, test loss: 0.5600, precision@k: 0.0435, recall@k: 0.1299, MAP@k: 0.0640, MRR@k: 0.1135, NDCG@k: 0.0961, HitRate@k: 0.2387
# Epoch 30, train loss: 0.3761, test loss: 0.5238, precision@k: 0.0441, recall@k: 0.1320, MAP@k: 0.0639, MRR@k: 0.1133, NDCG@k: 0.0967, HitRate@k: 0.2436
# Epoch 40, train loss: 0.3721, test loss: 0.5033, precision@k: 0.0448, recall@k: 0.1348, MAP@k: 0.0648, MRR@k: 0.1157, NDCG@k: 0.0983, HitRate@k: 0.2474
# Epoch 50, train loss: 0.3678, test loss: 0.4981, precision@k: 0.0451, recall@k: 0.1365, MAP@k: 0.0651, MRR@k: 0.1158, NDCG@k: 0.0990, HitRate@k: 0.2501
# Processing bootstrap dataset ix=9...
# Epoch 10, train loss: 0.4995, test loss: 0.5441, precision@k: 0.0447, recall@k: 0.1289, MAP@k: 0.0637, MRR@k: 0.1134, NDCG@k: 0.0960, HitRate@k: 0.2406
# Epoch 20, train loss: 0.3901, test loss: 0.5548, precision@k: 0.0439, recall@k: 0.1285, MAP@k: 0.0623, MRR@k: 0.1098, NDCG@k: 0.0944, HitRate@k: 0.2395
# Epoch 30, train loss: 0.3745, test loss: 0.5235, precision@k: 0.0446, recall@k: 0.1303, MAP@k: 0.0632, MRR@k: 0.1131, NDCG@k: 0.0960, HitRate@k: 0.2437
# Epoch 40, train loss: 0.3695, test loss: 0.5084, precision@k: 0.0452, recall@k: 0.1318, MAP@k: 0.0637, MRR@k: 0.1133, NDCG@k: 0.0969, HitRate@k: 0.2468
# Epoch 50, train loss: 0.3660, test loss: 0.5018, precision@k: 0.0458, recall@k: 0.1345, MAP@k: 0.0644, MRR@k: 0.1144, NDCG@k: 0.0981, HitRate@k: 0.2508

# %% [markdown]
# ### Model evaluation

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(f'../results/results_Model_bootstrapped_{model_name}.csv', index=False)

# %%
# Generate loss curve
# Train loss
sns.lineplot(data=results_df, x='Epoch', y='Train Loss')
# Test loss
sns.lineplot(data=results_df, x='Epoch', y='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss curve')
plt.yscale('log')
plt.show()

# %%
# Generate evaluation metrics plot
sns.lineplot(data=results_df, x='Epoch', y='Precision@k')
sns.lineplot(data=results_df, x='Epoch', y='Recall@k')
sns.lineplot(data=results_df, x='Epoch', y='MAP@k')
sns.lineplot(data=results_df, x='Epoch', y='MRR@k')
sns.lineplot(data=results_df, x='Epoch', y='NDCG@k')
sns.lineplot(data=results_df, x='Epoch', y='HitRate@k')
plt.xlabel('Epoch')
plt.ylabel('Performance')
plt.title('Performance metrics')
plt.show()
