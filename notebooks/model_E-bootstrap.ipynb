# %% [markdown]
# # Model E
#
# This is a script showing results of **model E** in the ablation studies. The model is built using the following configuration:
#
# - **Backbone:** GATv2
# - **Graph type:** Homogeneous
# - **Loss function:** Binary-Cross Entropy with Logits Loss
# - **Embeddings used:** average
# - **Keyword popularity used:** No
#
# *This model introduces a baseline loss function Binary-Cross Entropy with Logits loss to compare against Bayesian Personalized Ranking on graph attention network backbone.*

# %% [markdown]
# ## **Setting up environment**
#
# ---

# %% [markdown]
# ### Loading libraries

# %%
import os
import sys

sys.path.insert(0, os.path.abspath(".."))

import torch
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from typing import Optional

from torch import Tensor
from torch.nn import ModuleList
import torch.nn.functional as F
from torch.optim import Optimizer
from torch_geometric.typing import Adj, OptTensor
from torch_geometric.nn.conv import GATv2Conv
from torch.optim.lr_scheduler import LRScheduler
from torch_geometric.data import Data

from util.torch_geometric import get_results
from util.homogeneous.dataset import (DatasetEuCoHM, load_dataset)
from util.homogeneous.model import ModelEuCoHM
from util.homogeneous.train import (
    train,
    test,
    evaluate
)

# %% [markdown]
# ### Global variables

# %%
# Model name
model_name = 'E'
# Dataset save filepath
dataset_save_filepath_prefix = '../data/dataset_homogeneous_base'
# Device name
device = 'cpu'

# Model configuration
model_config = dict(
    hidden_channels=64,
    learning_rate=1e-3,
    num_layers=4,
    num_epochs=50,
    num_recommendations=10,
    num_bootstrap=10
)
# Set seaborn theme
sns.set_theme(style="whitegrid", palette="pastel")

# %% [markdown]
# ## Model training
#
#
# ---

# %% [markdown]
# ### Model definition

# %%
class ModelEuCoE(ModelEuCoHM):
    def __init__(self,
                 input_channels: int,
                 hidden_channels: int,
                 num_layers: int,
                 num_recommendations: int,
                 author_node_id_map: dict,
                 author_id_map: dict,
                 device: str = 'cpu'):
        super().__init__(
            input_channels=input_channels,
            hidden_channels=hidden_channels,
            num_layers=num_layers,
            num_recommendations=num_recommendations,
            author_node_id_map=author_node_id_map,
            author_id_map=author_id_map,
            device=device
        )

    
    def recommendation_loss(self,
                            x: Tensor,
                            edge_index: Adj,
                            pos_edge_rank: Tensor,
                            neg_edge_rank: Tensor,
                            edge_weight: Optional[Tensor] = None,
                            node_id: Optional[Tensor] = None) -> Tensor:

        # Construct labels
        pos_labels = pos_edge_rank.new_ones(pos_edge_rank.size(0))
        neg_labels = neg_edge_rank.new_zeros(neg_edge_rank.size(0))

        # Concatenate predictions and labels
        all_preds = torch.cat([pos_edge_rank, neg_edge_rank], dim=0)
        all_labels = torch.cat([pos_labels, neg_labels], dim=0)

        # Compute BCE loss
        bce_loss = F.binary_cross_entropy_with_logits(all_preds, all_labels)

        return bce_loss

# %% [markdown]
# ### Training the model

# %%
def load_model(data: Data, model_config: dict, author_node_id_map: dict, author_id_map: dict):
    # Initialize the model
    model = ModelEuCoE(
        input_channels=data.num_features,
        hidden_channels=model_config['hidden_channels'],
        num_recommendations=model_config['num_recommendations'],
        num_layers=model_config['num_layers'],
        author_node_id_map=author_node_id_map,
        author_id_map=author_id_map
    ).to(device)
    
    # Initialize the optimizer
    optimizer: Optimizer = torch.optim.Adam(
        params=model.parameters(),
        lr=model_config['learning_rate']
    )
    
    # Initialize the scheduler
    scheduler: LRScheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer=optimizer,
        mode='min',
        factor=0.5,
        patience=10
    )
    
    return model, data, optimizer, scheduler

# %%
results: list = list()
for bootstrap_id in range(model_config['num_bootstrap']):
    print(f'Processing bootstrap dataset ix={bootstrap_id}...')
    dataset_filepath = f'{dataset_save_filepath_prefix}_b{bootstrap_id}.pkl'
    data, author_id_map, author_node_id_map = load_dataset(dataset_filepath=dataset_filepath, device=device)
    model, data, optimizer, scheduler = load_model(data, model_config, author_node_id_map, author_id_map)
    for epoch in range(1, model_config['num_epochs'] + 1):
        # ------ Train
        train_loss: float = train(
            model=model,
            data=data,
            optimizer=optimizer
        )
        # ------ Test
        test_loss: float = test(
            model=model,
            data=data
        )
        scheduler.step(test_loss)
        # ------ Evaluate
        evaluation_results: dict = evaluate(
            k=model_config['num_recommendations'],
            model=model,
            data=data
        )
    
        # Save results
        epoch_result = get_results(
            epoch=epoch,
            train_loss=train_loss,
            test_loss=test_loss,
            evaluation_results=evaluation_results,
            bootstrap_id=bootstrap_id,
            log_every_n_epochs=10
        )
        results.append(epoch_result)
# Out:
# Processing bootstrap dataset ix=0...
# /home/eucollab/eutopia-colllaboration/ecr-recommender/.venv/lib/python3.12/site-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# Epoch 10, train loss: 0.4183, test loss: 0.4840, precision@k: 0.0494, recall@k: 0.1529, MAP@k: 0.0808, MRR@k: 0.1344, NDCG@k: 0.1160, HitRate@k: 0.2670
# Epoch 20, train loss: 0.4027, test loss: 0.4478, precision@k: 0.0525, recall@k: 0.1640, MAP@k: 0.0892, MRR@k: 0.1463, NDCG@k: 0.1257, HitRate@k: 0.2805
# Epoch 30, train loss: 0.3939, test loss: 0.4338, precision@k: 0.0563, recall@k: 0.1751, MAP@k: 0.0953, MRR@k: 0.1555, NDCG@k: 0.1342, HitRate@k: 0.2956
# Epoch 40, train loss: 0.3892, test loss: 0.4294, precision@k: 0.0578, recall@k: 0.1801, MAP@k: 0.0957, MRR@k: 0.1553, NDCG@k: 0.1358, HitRate@k: 0.3020
# Epoch 50, train loss: 0.3845, test loss: 0.4288, precision@k: 0.0583, recall@k: 0.1819, MAP@k: 0.0963, MRR@k: 0.1563, NDCG@k: 0.1368, HitRate@k: 0.3054
# Processing bootstrap dataset ix=1...
# Epoch 10, train loss: 0.4224, test loss: 0.4943, precision@k: 0.0498, recall@k: 0.1527, MAP@k: 0.0807, MRR@k: 0.1314, NDCG@k: 0.1152, HitRate@k: 0.2631
# Epoch 20, train loss: 0.4053, test loss: 0.4494, precision@k: 0.0541, recall@k: 0.1677, MAP@k: 0.0900, MRR@k: 0.1463, NDCG@k: 0.1274, HitRate@k: 0.2870
# Epoch 30, train loss: 0.3970, test loss: 0.4358, precision@k: 0.0563, recall@k: 0.1754, MAP@k: 0.0921, MRR@k: 0.1507, NDCG@k: 0.1316, HitRate@k: 0.2978
# Epoch 40, train loss: 0.3899, test loss: 0.4298, precision@k: 0.0587, recall@k: 0.1821, MAP@k: 0.0957, MRR@k: 0.1555, NDCG@k: 0.1365, HitRate@k: 0.3057
# Epoch 50, train loss: 0.3858, test loss: 0.4277, precision@k: 0.0600, recall@k: 0.1850, MAP@k: 0.0968, MRR@k: 0.1572, NDCG@k: 0.1383, HitRate@k: 0.3088
# Processing bootstrap dataset ix=2...
# Epoch 10, train loss: 0.4075, test loss: 0.4651, precision@k: 0.0526, recall@k: 0.1610, MAP@k: 0.0857, MRR@k: 0.1433, NDCG@k: 0.1228, HitRate@k: 0.2799
# Epoch 20, train loss: 0.3976, test loss: 0.4395, precision@k: 0.0559, recall@k: 0.1729, MAP@k: 0.0907, MRR@k: 0.1471, NDCG@k: 0.1296, HitRate@k: 0.2947
# Epoch 30, train loss: 0.3907, test loss: 0.4293, precision@k: 0.0585, recall@k: 0.1808, MAP@k: 0.0957, MRR@k: 0.1533, NDCG@k: 0.1357, HitRate@k: 0.3037
# Epoch 40, train loss: 0.3857, test loss: 0.4253, precision@k: 0.0610, recall@k: 0.1867, MAP@k: 0.0974, MRR@k: 0.1569, NDCG@k: 0.1392, HitRate@k: 0.3127
# Epoch 50, train loss: 0.3806, test loss: 0.4246, precision@k: 0.0601, recall@k: 0.1836, MAP@k: 0.0966, MRR@k: 0.1549, NDCG@k: 0.1374, HitRate@k: 0.3080
# Processing bootstrap dataset ix=3...
# Epoch 10, train loss: 0.4125, test loss: 0.4707, precision@k: 0.0501, recall@k: 0.1565, MAP@k: 0.0798, MRR@k: 0.1314, NDCG@k: 0.1160, HitRate@k: 0.2732
# Epoch 20, train loss: 0.4005, test loss: 0.4414, precision@k: 0.0528, recall@k: 0.1695, MAP@k: 0.0849, MRR@k: 0.1382, NDCG@k: 0.1235, HitRate@k: 0.2861
# Epoch 30, train loss: 0.3922, test loss: 0.4305, precision@k: 0.0564, recall@k: 0.1779, MAP@k: 0.0902, MRR@k: 0.1451, NDCG@k: 0.1305, HitRate@k: 0.3000
# Epoch 40, train loss: 0.3865, test loss: 0.4277, precision@k: 0.0589, recall@k: 0.1870, MAP@k: 0.0945, MRR@k: 0.1523, NDCG@k: 0.1366, HitRate@k: 0.3133
# Epoch 50, train loss: 0.3832, test loss: 0.4280, precision@k: 0.0599, recall@k: 0.1896, MAP@k: 0.0976, MRR@k: 0.1575, NDCG@k: 0.1400, HitRate@k: 0.3187
# Processing bootstrap dataset ix=4...
# Epoch 10, train loss: 0.4177, test loss: 0.4776, precision@k: 0.0490, recall@k: 0.1551, MAP@k: 0.0786, MRR@k: 0.1281, NDCG@k: 0.1138, HitRate@k: 0.2669
# Epoch 20, train loss: 0.4028, test loss: 0.4431, precision@k: 0.0523, recall@k: 0.1697, MAP@k: 0.0863, MRR@k: 0.1404, NDCG@k: 0.1246, HitRate@k: 0.2900
# Epoch 30, train loss: 0.3960, test loss: 0.4319, precision@k: 0.0535, recall@k: 0.1748, MAP@k: 0.0877, MRR@k: 0.1436, NDCG@k: 0.1273, HitRate@k: 0.2972
# Epoch 40, train loss: 0.3898, test loss: 0.4282, precision@k: 0.0560, recall@k: 0.1827, MAP@k: 0.0928, MRR@k: 0.1509, NDCG@k: 0.1339, HitRate@k: 0.3093
# Epoch 50, train loss: 0.3856, test loss: 0.4268, precision@k: 0.0572, recall@k: 0.1863, MAP@k: 0.0947, MRR@k: 0.1548, NDCG@k: 0.1364, HitRate@k: 0.3141
# Processing bootstrap dataset ix=5...
# Epoch 10, train loss: 0.4119, test loss: 0.4779, precision@k: 0.0493, recall@k: 0.1539, MAP@k: 0.0803, MRR@k: 0.1369, NDCG@k: 0.1163, HitRate@k: 0.2713
# Epoch 20, train loss: 0.4004, test loss: 0.4439, precision@k: 0.0562, recall@k: 0.1732, MAP@k: 0.0910, MRR@k: 0.1515, NDCG@k: 0.1309, HitRate@k: 0.2986
# Epoch 30, train loss: 0.3932, test loss: 0.4338, precision@k: 0.0589, recall@k: 0.1826, MAP@k: 0.0946, MRR@k: 0.1550, NDCG@k: 0.1364, HitRate@k: 0.3110
# Epoch 40, train loss: 0.3870, test loss: 0.4300, precision@k: 0.0599, recall@k: 0.1838, MAP@k: 0.0971, MRR@k: 0.1583, NDCG@k: 0.1388, HitRate@k: 0.3095
# Epoch 50, train loss: 0.3827, test loss: 0.4299, precision@k: 0.0604, recall@k: 0.1856, MAP@k: 0.0953, MRR@k: 0.1538, NDCG@k: 0.1374, HitRate@k: 0.3114
# Processing bootstrap dataset ix=6...
# Epoch 10, train loss: 0.4130, test loss: 0.4703, precision@k: 0.0517, recall@k: 0.1602, MAP@k: 0.0813, MRR@k: 0.1372, NDCG@k: 0.1189, HitRate@k: 0.2802
# Epoch 20, train loss: 0.4002, test loss: 0.4381, precision@k: 0.0554, recall@k: 0.1725, MAP@k: 0.0897, MRR@k: 0.1473, NDCG@k: 0.1287, HitRate@k: 0.2940
# Epoch 30, train loss: 0.3934, test loss: 0.4258, precision@k: 0.0572, recall@k: 0.1790, MAP@k: 0.0942, MRR@k: 0.1551, NDCG@k: 0.1345, HitRate@k: 0.3039
# Epoch 40, train loss: 0.3884, test loss: 0.4221, precision@k: 0.0594, recall@k: 0.1852, MAP@k: 0.0966, MRR@k: 0.1578, NDCG@k: 0.1384, HitRate@k: 0.3132
# Epoch 50, train loss: 0.3836, test loss: 0.4217, precision@k: 0.0600, recall@k: 0.1850, MAP@k: 0.0969, MRR@k: 0.1587, NDCG@k: 0.1388, HitRate@k: 0.3136
# Processing bootstrap dataset ix=7...
# Epoch 10, train loss: 0.4126, test loss: 0.4754, precision@k: 0.0498, recall@k: 0.1551, MAP@k: 0.0815, MRR@k: 0.1341, NDCG@k: 0.1166, HitRate@k: 0.2681
# Epoch 20, train loss: 0.4002, test loss: 0.4425, precision@k: 0.0522, recall@k: 0.1662, MAP@k: 0.0870, MRR@k: 0.1435, NDCG@k: 0.1244, HitRate@k: 0.2817
# Epoch 30, train loss: 0.3938, test loss: 0.4318, precision@k: 0.0559, recall@k: 0.1775, MAP@k: 0.0934, MRR@k: 0.1511, NDCG@k: 0.1327, HitRate@k: 0.2983
# Epoch 40, train loss: 0.3882, test loss: 0.4262, precision@k: 0.0579, recall@k: 0.1837, MAP@k: 0.0971, MRR@k: 0.1551, NDCG@k: 0.1374, HitRate@k: 0.3079
# Epoch 50, train loss: 0.3835, test loss: 0.4250, precision@k: 0.0588, recall@k: 0.1864, MAP@k: 0.0982, MRR@k: 0.1576, NDCG@k: 0.1392, HitRate@k: 0.3099
# Processing bootstrap dataset ix=8...
# Epoch 10, train loss: 0.4095, test loss: 0.4617, precision@k: 0.0515, recall@k: 0.1609, MAP@k: 0.0840, MRR@k: 0.1386, NDCG@k: 0.1206, HitRate@k: 0.2783
# Epoch 20, train loss: 0.3981, test loss: 0.4367, precision@k: 0.0567, recall@k: 0.1745, MAP@k: 0.0917, MRR@k: 0.1483, NDCG@k: 0.1310, HitRate@k: 0.2952
# Epoch 30, train loss: 0.3910, test loss: 0.4292, precision@k: 0.0579, recall@k: 0.1802, MAP@k: 0.0955, MRR@k: 0.1543, NDCG@k: 0.1357, HitRate@k: 0.3026
# Epoch 40, train loss: 0.3861, test loss: 0.4267, precision@k: 0.0593, recall@k: 0.1849, MAP@k: 0.0968, MRR@k: 0.1564, NDCG@k: 0.1381, HitRate@k: 0.3065
# Epoch 50, train loss: 0.3811, test loss: 0.4277, precision@k: 0.0597, recall@k: 0.1856, MAP@k: 0.0959, MRR@k: 0.1549, NDCG@k: 0.1376, HitRate@k: 0.3118
# Processing bootstrap dataset ix=9...
# Epoch 10, train loss: 0.4134, test loss: 0.4761, precision@k: 0.0512, recall@k: 0.1573, MAP@k: 0.0819, MRR@k: 0.1328, NDCG@k: 0.1174, HitRate@k: 0.2682
# Epoch 20, train loss: 0.4022, test loss: 0.4447, precision@k: 0.0554, recall@k: 0.1698, MAP@k: 0.0885, MRR@k: 0.1430, NDCG@k: 0.1267, HitRate@k: 0.2896
# Epoch 30, train loss: 0.3939, test loss: 0.4334, precision@k: 0.0575, recall@k: 0.1767, MAP@k: 0.0914, MRR@k: 0.1467, NDCG@k: 0.1310, HitRate@k: 0.2987
# Epoch 40, train loss: 0.3878, test loss: 0.4284, precision@k: 0.0589, recall@k: 0.1816, MAP@k: 0.0956, MRR@k: 0.1528, NDCG@k: 0.1358, HitRate@k: 0.3055
# Epoch 50, train loss: 0.3844, test loss: 0.4284, precision@k: 0.0593, recall@k: 0.1836, MAP@k: 0.0961, MRR@k: 0.1533, NDCG@k: 0.1369, HitRate@k: 0.3098

# %% [markdown]
# ### Model evaluation

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(f'../results/results_Model_bootstrapped_{model_name}.csv', index=False)

# %%
# Generate loss curve
# Train loss
sns.lineplot(data=results_df, x='Epoch', y='Train Loss')
# Test loss
sns.lineplot(data=results_df, x='Epoch', y='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss curve')
plt.yscale('log')
plt.show()

# %%
# Generate evaluation metrics plot
sns.lineplot(data=results_df, x='Epoch', y='Precision@k')
sns.lineplot(data=results_df, x='Epoch', y='Recall@k')
sns.lineplot(data=results_df, x='Epoch', y='MAP@k')
sns.lineplot(data=results_df, x='Epoch', y='MRR@k')
sns.lineplot(data=results_df, x='Epoch', y='NDCG@k')
sns.lineplot(data=results_df, x='Epoch', y='HitRate@k')
plt.xlabel('Epoch')
plt.ylabel('Performance')
plt.title('Performance metrics')
plt.show()
